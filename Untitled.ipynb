# %%
# !pip install kagglehub --upgrade
# Out:
# Requirement already satisfied: kagglehub in c:\users\lenovo\anaconda3\lib\site-packages (0.3.12)
# Requirement already satisfied: packaging in c:\users\lenovo\anaconda3\lib\site-packages (from kagglehub) (24.1)
# Requirement already satisfied: pyyaml in c:\users\lenovo\anaconda3\lib\site-packages (from kagglehub) (6.0.1)
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\lib\site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\lenovo\anaconda3\lib\site-packages (from kagglehub) (4.66.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->kagglehub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->kagglehub) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from tqdm->kagglehub) (0.4.6)

# %%
import kagglehub  #kagglehub is a python library to download dataset from kaggle

# %%
#dataset_download() is a function provided by the kagglehub library to download a dataset using its Kaggle ID.

# %%
kagglehub.dataset_download("undefinenull/million-song-dataset-spotify-lastfm") #where undefinenull is the user id and baaki is the dataset name
# Out:
# 'C:\\Users\\Lenovo\\.cache\\kagglehub\\datasets\\undefinenull\\million-song-dataset-spotify-lastfm\\versions\\1'

# %%
import os
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = Path("C:\\Users\\Lenovo\\.cache\\kagglehub\\datasets\\undefinenull\\million-song-dataset-spotify-lastfm\\versions\\1")


songs_data_path = data_path / 'Music Info.csv'
users_data_path = data_path / 'User Listening History.csv'

# %% [markdown]
# ## **Songs Dataset** ######

# %%
df_songs=pd.read_csv(songs_data_path)
df_songs.head(3)
# Out:
#              track_id             name       artist  \
# 0  TRIOREW128F424EAF0   Mr. Brightside  The Killers
# 1  TRRIVDJ128F429B0E8       Wonderwall        Oasis
# 2  TROUVHL128F426C441  Come as You Are      Nirvana
#
#                                  spotify_preview_url              spotify_id  \
# 0  https://p.scdn.co/mp3-preview/4d26180e6961fd46...  09ZQ5TmUG8TSL56n0knqrj
# 1  https://p.scdn.co/mp3-preview/d012e536916c927b...  06UfBBDISthj1ZJAtX4xjj
# 2  https://p.scdn.co/mp3-preview/a1c11bb1cb231031...  0keNu0t0tqsWtExGM3nT1D
#
#                                                 tags genre  year  duration_ms  \
# 0  rock, alternative, indie, alternative_rock, in...   NaN  2004       222200
# 1  rock, alternative, indie, pop, alternative_roc...   NaN  2006       258613
# 2   rock, alternative, alternative_rock, 90s, grunge   RnB  1991       218920
#
#    danceability  ...  key  loudness  mode  speechiness  acousticness  \
# 0         0.355  ...    1    -4.360     1       0.0746      0.001190
# 1         0.409  ...    2    -4.373     1       0.0336      0.000807
# 2         0.508  ...    4    -5.783     0       0.0400      0.000175
#
#    instrumentalness  liveness  valence    tempo  time_signature
# 0          0.000000    0.0971    0.240  148.114               4
# 1          0.000000    0.2070    0.651  174.426               4
# 2          0.000459    0.0878    0.543  120.012               4
#
# [3 rows x 21 columns]

# %% [markdown]
# ## Preliminary Analysis

# %%
#size of dataset

df_songs.shape
# Out:
# (50683, 21)

# %%
#data info

df_songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50683 entries, 0 to 50682
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   track_id             50683 non-null  object
#  1   name                 50683 non-null  object
#  2   artist               50683 non-null  object
#  3   spotify_preview_url  50683 non-null  object
#  4   spotify_id           50683 non-null  object
#  5   tags                 49556 non-null  object
#  6   genre                22348 non-null  object
#  7   year                 50683 non-null  int64
#  8   duration_ms          50683 non-null  int64
#  9   danceability         50683 non-null  float64
#  10  energy               50683 non-null  float64
#  11  key                  50683 non-null  int64
#  12  loudness             50683 non-null  float64
#  13  mode                 50683 non-null  int64
#  14  speechiness          50683 non-null  float64
#  15  acousticness         50683 non-null  float64
#  16  instrumentalness     50683 non-null  float64
#  17  liveness             50683 non-null  float64
#  18  valence              50683 non-null  float64
#  19  tempo                50683 non-null  float64
#  20  time_signature       50683 non-null  int64
# dtypes: float64(9), int64(5), object(7)
# memory usage: 8.1+ MB

# %%
#genre mai bohot missing values hai, tags mai thode kam missing value hai

# %%
#drop columns from dataset, preview ki abhi zarurat nhi

columns_to_drop=['spotify_preview_url']
df_songs.drop(columns=columns_to_drop, inplace=True)
df_songs.head()
# Out:
#              track_id             name           artist  \
# 0  TRIOREW128F424EAF0   Mr. Brightside      The Killers
# 1  TRRIVDJ128F429B0E8       Wonderwall            Oasis
# 2  TROUVHL128F426C441  Come as You Are          Nirvana
# 3  TRUEIND128F93038C4      Take Me Out  Franz Ferdinand
# 4  TRLNZBD128F935E4D8            Creep        Radiohead
#
#                spotify_id                                               tags  \
# 0  09ZQ5TmUG8TSL56n0knqrj  rock, alternative, indie, alternative_rock, in...
# 1  06UfBBDISthj1ZJAtX4xjj  rock, alternative, indie, pop, alternative_roc...
# 2  0keNu0t0tqsWtExGM3nT1D   rock, alternative, alternative_rock, 90s, grunge
# 3  0ancVQ9wEcHVd0RrGICTE4  rock, alternative, indie, alternative_rock, in...
# 4  01QoK9DA7VTeTSE3MNzp4I  rock, alternative, indie, alternative_rock, in...
#
#   genre  year  duration_ms  danceability  energy  key  loudness  mode  \
# 0   NaN  2004       222200         0.355   0.918    1    -4.360     1
# 1   NaN  2006       258613         0.409   0.892    2    -4.373     1
# 2   RnB  1991       218920         0.508   0.826    4    -5.783     0
# 3   NaN  2004       237026         0.279   0.664    9    -8.851     1
# 4   RnB  2008       238640         0.515   0.430    7    -9.935     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0746      0.001190          0.000000    0.0971    0.240  148.114
# 1       0.0336      0.000807          0.000000    0.2070    0.651  174.426
# 2       0.0400      0.000175          0.000459    0.0878    0.543  120.012
# 3       0.0371      0.000389          0.000655    0.1330    0.490  104.560
# 4       0.0369      0.010200          0.000141    0.1290    0.104   91.841
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %% [markdown]
# ## Missing Values

# %%
df_songs['genre'].isna().sum()
# Out:
# 28335

# %%
df_songs.isna().sum()
# Out:
# track_id                0
# name                    0
# artist                  0
# spotify_id              0
# tags                 1127
# genre               28335
# year                    0
# duration_ms             0
# danceability            0
# energy                  0
# key                     0
# loudness                0
# mode                    0
# speechiness             0
# acousticness            0
# instrumentalness        0
# liveness                0
# valence                 0
# tempo                   0
# time_signature          0
# dtype: int64

# %%
import missingno as msno

# %%
# !pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\lenovo\anaconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (from missingno) (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\lenovo\anaconda3\lib\site-packages (from missingno) (3.9.2)
# Requirement already satisfied: scipy in c:\users\lenovo\anaconda3\lib\site-packages (from missingno) (1.13.1)
# Requirement already satisfied: seaborn in c:\users\lenovo\anaconda3\lib\site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib->missingno) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib->missingno) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib->missingno) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib->missingno) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib->missingno) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\lenovo\anaconda3\lib\site-packages (from seaborn->missingno) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)

# %%
msno.matrix(df_songs)
# Out:
# <Axes: >

# %% [markdown]
# #genre mai to randomly data bohot missing hai with no pattern, tag mai aakhri mai missing hai bas

# %%
# ratio of missing values in data

df_songs.isna().mean().mul(100).round(2).sort_values(ascending=False).head(2)
# Out:
# genre    55.91
# tags      2.22
# dtype: float64

# %% [markdown]
# ## Duplicates in data

# %%
#check for duplicates based on name of then song

# %%
# assign temporaily replaces name col in copy of df_songs
df_songs.assign(name=df_songs['name'].str.lower()).duplicated(subset='name').sum()
# Out:
# 815

# %%
# rows that are duplicate

(
    df_songs
    .loc[
        df_songs
        .assign(name=df_songs['name'].str.lower())
        .duplicated(subset='name',keep=False)
    ]
    .assign(name=df_songs['name'].str.lower())
    .sort_values("name")
)
# Out:
#                  track_id                            name  \
# 34480  TRKKZMK128F4257579                            3 am
# 6588   TRGGALK12903CB68E5                            3 am
# 29795  TRLOXMF128F934BF04                             3am
# 43800  TRPWOAS128E0781045                             3am
# 15088  TRJRBRX128F4255789                     4th of july
# ...                   ...                             ...
# 34772  TRJFGYO128F4259743      you're the one that i want
# 32677  TRFZYLL128F146902A  you've really got a hold on me
# 20976  TRUXHGS128F145E41A  you've really got a hold on me
# 27680  TRXWPMW12903CB42A0                         zombies
# 37428  TRORIUQ128F42620A3                         zombies
#
#                                  artist              spotify_id  \
# 34480                      Liv Kristine  1TgsnkiolcBhQssCR37JXx
# 6588                    Matchbox Twenty  5vYA1mW9g2Coh1HUFUSmlb
# 29795                   Matchbox Twenty  5vYA1mW9g2Coh1HUFUSmlb
# 43800                            Halsey  1OfLNb6dQ9dra1B58iT9Ex
# 15088                       Soundgarden  237oH9rNUYpIBeHfAn3WJ0
# ...                                 ...                     ...
# 34772                           Lo-Fang  1dEHQktvcM8vCCyI1x7yVB
# 32677  Smokey Robinson and The Miracles  03AkIZeRvGpTvDF9vNJtdj
# 20976                      The Miracles  01FtGX94CSvO5Zxs5B6AMM
# 27680                  Childish Gambino  73kAUSAht4YOR7xNPmNb2L
# 37428                       Lacuna Coil  02J446tHHPvSSNeLxW8Lg6
#
#                                                     tags genre  year  \
# 34480  female_vocalists, power_metal, gothic_metal, g...   NaN  2005
# 6588   rock, alternative, pop, alternative_rock, 90s,...   NaN  1996
# 29795  rock, alternative, 90s, piano, american, pop_rock   NaN  1996
# 43800                                           pop_rock   NaN  2020
# 15088                             hard_rock, 90s, grunge   NaN  1994
# ...                                                  ...   ...   ...
# 34772                       indie, male_vocalists, cover   NaN  2014
# 32677                                  soul, 60s, oldies  Rock  2012
# 20976                                  soul, 60s, oldies   NaN  1994
# 27680                                               funk   NaN  2016
# 37428                               gothic_metal, gothic   NaN  2014
#
#        duration_ms  danceability  energy  key  loudness  mode  speechiness  \
# 34480       302880         0.516   0.840    0    -6.038     0       0.0390
# 6588        225946         0.521   0.673    8    -8.685     1       0.0284
# 29795       225946         0.521   0.673    8    -8.685     1       0.0284
# 43800       234858         0.385   0.871    0    -4.604     0       0.0795
# 15088       308866         0.368   0.749    5    -5.523     0       0.0392
# ...            ...           ...     ...  ...       ...   ...          ...
# 34772       204706         0.445   0.309   11   -12.517     0       0.0404
# 32677       179513         0.674   0.515    0    -6.895     1       0.0296
# 20976       180266         0.679   0.406    0   -10.533     1       0.0312
# 27680       281813         0.653   0.411    0   -11.986     1       0.1270
# 37428       227440         0.402   0.962    8    -2.988     1       0.0629
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 34480      0.152000          0.005970     0.107    0.441   78.009
# 6588       0.005730          0.000000     0.120    0.543  108.031
# 29795      0.005730          0.000000     0.120    0.543  108.031
# 43800      0.009060          0.000000     0.579    0.538  189.760
# 15088      0.109000          0.000372     0.175    0.193  141.901
# ...             ...               ...       ...      ...      ...
# 34772      0.643000          0.000369     0.224    0.153  119.754
# 32677      0.724000          0.000000     0.339    0.596  116.678
# 20976      0.755000          0.000000     0.412    0.511  117.940
# 27680      0.503000          0.000969     0.067    0.468  160.055
# 37428      0.000895          0.000011     0.090    0.496   80.972
#
#        time_signature
# 34480               4
# 6588                4
# 29795               4
# 43800               4
# 15088               4
# ...               ...
# 34772               4
# 32677               3
# 20976               3
# 27680               4
# 37428               4
#
# [1614 rows x 20 columns]

# %%
# duplicates in the data based on spotify_id

df_songs.duplicated(subset='spotify_id').sum()
# Out:
# 9

# %%
# duplicate songs in the data


df_songs.duplicated(subset=['spotify_id', 'year', 'duration_ms']).sum()
# Out:
# 9

# %% [markdown]
# ## 9 Duplicates song in the data

# %%
#rows that have duplicated data
df_songs[df_songs.duplicated(subset=['spotify_id', 'year', 'duration_ms'])]
# Out:
#                  track_id                        name               artist  \
# 2983   TRXFHCL128F92E0989                There, There            Radiohead
# 14981  TRXHJQY128F42B5094            How Do U Want It                 2Pac
# 21570  TRLSRQD128F426CFF8  Adagio for Strings, Op. 11        Samuel Barber
# 26389  TRCUHWL128F4249F1A                    Hallmark  Broken Social Scene
# 29795  TRLOXMF128F934BF04                         3AM      Matchbox Twenty
# 32191  TRCEFVZ128F4283203            The Greatest Hit                Annie
# 42187  TRVENST12903D13BBB          Do You Love Me Now         The Breeders
# 46512  TRDTUTO128F422F138   Too Much Too Young (Live)         The Specials
# 49162  TRZBNQU128F148C04F              Je Pense A Toi      Amadou & Mariam
#
#                    spotify_id  \
# 2983   0thdzbW0cRKCx12VbBRB6T
# 14981  02VsIBmSkhc7uHNyPViZR3
# 21570  00otCiz9kUb3Vg7LPKNCZG
# 26389  1Ntzk4JoxcAsrWi73MoBjr
# 29795  5vYA1mW9g2Coh1HUFUSmlb
# 32191  3MUviQJP5DSYI3Li4EbYTQ
# 42187  22Ty5gK6zbw0hRtGypTuX5
# 46512  0ndKJL8gA4zLl317M7vndn
# 49162  09jsAIZF9ThihIzdrw4KAS
#
#                                                     tags genre  year  \
# 2983   rock, electronic, alternative, indie, alternat...   NaN  2008
# 14981                             rap, hip_hop, american   Rap  2011
# 21570                                          classical   NaN  2014
# 26389   indie, alternative_rock, instrumental, post_rock   NaN  2004
# 29795  rock, alternative, 90s, piano, american, pop_rock   NaN  1996
# 32191  electronic, pop, female_vocalists, dance, electro   NaN  2004
# 42187  rock, alternative, indie, female_vocalists, al...   NaN  1993
# 46512                                                ska   NaN  2012
# 49162                                                NaN   NaN  2005
#
#        duration_ms  danceability  energy  key  loudness  mode  speechiness  \
# 2983        323600         0.614  0.6770    9    -8.317     0       0.0323
# 14981       289000         0.832  0.7850    8    -2.859     1       0.0930
# 21570       431412         0.140  0.0947   10   -18.599     0       0.0458
# 26389       233706         0.523  0.5830    0   -10.694     1       0.0434
# 29795       225946         0.521  0.6730    8    -8.685     1       0.0284
# 32191       220293         0.786  0.8540   10    -3.249     0       0.1380
# 42187       181800         0.486  0.2330    2   -11.535     1       0.0365
# 46512       116160         0.597  0.8390    2    -9.052     1       0.0471
# 49162       316880         0.680  0.3990   11   -11.585     0       0.0279
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 2983        0.01930          0.518000    0.1080   0.7170  126.477
# 14981       0.11100          0.000007    0.0623   0.8120   92.468
# 21570       0.97800          0.478000    0.0735   0.0365   84.560
# 26389       0.08790          0.109000    0.1440   0.1720  119.980
# 29795       0.00573          0.000000    0.1200   0.5430  108.031
# 32191       0.00261          0.000171    0.1550   0.5470  127.128
# 42187       0.03190          0.107000    0.1020   0.3200  134.187
# 46512       0.44700          0.000134    0.3100   0.9650  156.058
# 49162       0.74900          0.001610    0.1580   0.8280  106.349
#
#        time_signature
# 2983                4
# 14981               4
# 21570               4
# 26389               3
# 29795               4
# 32191               4
# 42187               4
# 46512               4
# 49162               4

# %%
#drop the 9 duplicates

df_songs.drop_duplicates(subset=['spotify_id', 'year', 'duration_ms'], inplace=True)

# %%
#recheck duplicated

df_songs.duplicated(subset=['spotify_id', 'year', 'duration_ms']).sum()
# Out:
# 0

# %% [markdown]
# ##### duplicates are removed

# %% [markdown]
# ## Column Wise analysis

# %% [markdown]
# #### Categorical column

# %%
#list of columns

df_songs.columns
# Out:
# Index(['track_id', 'name', 'artist', 'spotify_id', 'tags', 'genre', 'year',
#        'duration_ms', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
df_songs.dtypes
# Out:
# track_id             object
# name                 object
# artist               object
# spotify_id           object
# tags                 object
# genre                object
# year                  int64
# duration_ms           int64
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# dtype: object

# %%
# Categorical Columns

categorical_features = df_songs.select_dtypes(include="object").columns
categorical_features
# Out:
# Index(['track_id', 'name', 'artist', 'spotify_id', 'tags', 'genre'], dtype='object')

# %%
def categorical_analysis(df,feature_names,k_artists=15):
    for feature in feature_names:
        print(f"Number of categories in column {feature} are ",df[feature].str.lower().nunique())

        if feature in ["artist","genre"]:
            print(df[feature].value_counts().head(k_artists))

        if feature == "genre":
            print(f"The unique categories in {feature} column are: ", df[feature].dropna().unique())
        print("#" * 75)

# %%
categorical_analysis(df_songs,categorical_features)
# Out:
# Number of categories in column track_id are  50674
# ###########################################################################
# Number of categories in column name are  49860
# ###########################################################################
# Number of categories in column artist are  8317
# artist
# The Rolling Stones    132
# Radiohead             110
# Autechre              105
# Tom Waits             100
# Bob Dylan              98
# The Cure               94
# Metallica              85
# Johnny Cash            84
# Nine Inch Nails        83
# Sonic Youth            81
# Elliott Smith          76
# Iron Maiden            76
# In Flames              76
# Boards of Canada       75
# Mogwai                 75
# Name: count, dtype: int64
# ###########################################################################
# Number of categories in column spotify_id are  50674
# ###########################################################################
# Number of categories in column tags are  20054
# ###########################################################################
# Number of categories in column genre are  15
# genre
# Rock          9965
# Electronic    3710
# Metal         2516
# Pop           1145
# Rap            820
# Jazz           793
# RnB            696
# Reggae         691
# Country        607
# Punk           383
# Folk           355
# New Age        237
# Blues          189
# World          140
# Latin          100
# Name: count, dtype: int64
# The unique categories in genre column are:  ['RnB' 'Rock' 'Pop' 'Metal' 'Electronic' 'Jazz' 'Punk' 'Country' 'Folk'
#  'Reggae' 'Rap' 'Blues' 'New Age' 'Latin' 'World']
# ###########################################################################

# %% [markdown]
# ### **Observations**:
# 1. The `Track ID` and `Spotify ID`'s are unique for every row.
# 2. The song names have some repititions. That is because there are a few songs in the data whose name is the same but is sung by a different artist.
# 3. The dataset contains songs of about `8317 artists`.
# 4. There are 15 distinct categories in the `Genre` column.

# %%
# countplot of genre

sns.countplot(df_songs,x="genre")
plt.xticks(rotation=90)
plt.show()

# %%
# genre group

genre_group=df_songs.groupby("genre")
genre_group[['genre', 'tags']].sample(3)
# Out:
#             genre                                               tags
# 44426       Blues  classic_rock, british, blues, piano, 60s, blue...
# 23599       Blues         indie, british, blues, acoustic, indie_pop
# 10879       Blues  classic_rock, blues, acoustic, guitar, blues_rock
# 23223     Country                                soundtrack, country
# 33372     Country                                            country
# 33344     Country                                            country
# 7367   Electronic      rock, metal, hard_rock, heavy_metal, nu_metal
# 42171  Electronic                                                NaN
# 2920   Electronic  electronic, ambient, instrumental, chillout, t...
# 46813        Folk                                          post_punk
# 23853        Folk     rock, folk, singer_songwriter, blues, acoustic
# 50213        Folk  female_vocalists, folk, singer_songwriter, aco...
# 9513         Jazz                  jazz, chillout, downtempo, lounge
# 2070         Jazz                rock, classic_rock, soul, funk, 70s
# 23208        Jazz  alternative, indie, instrumental, soundtrack, ...
# 40673       Latin                                              cover
# 45895       Latin                                                ska
# 46524       Latin                                                ska
# 19055       Metal  death_metal, progressive_metal, melodic_death_...
# 7509        Metal   metal, classic_rock, hard_rock, heavy_metal, 70s
# 37414       Metal                        metal, gothic_metal, gothic
# 45312     New Age                       electronic, ambient, new_age
# 45684     New Age                                   ambient, new_age
# 45389     New Age                                   ambient, new_age
# 33874         Pop  alternative, pop, alternative_rock, british, s...
# 37207         Pop                          electronic, 70s, synthpop
# 38840         Pop             electronic, ambient, experimental, idm
# 30868        Punk                       punk, punk_rock, reggae, ska
# 22211        Punk                             rap, hip_hop, american
# 13402        Punk                                    punk, punk_rock
# 16798         Rap          rock, singer_songwriter, british, britpop
# 41017         Rap                     electronic, indie_pop, swedish
# 31498         Rap                            techno, electro, french
# 46489      Reggae                                                ska
# 30494      Reggae                                        reggae, ska
# 30425      Reggae                                             reggae
# 22273         RnB             metal, industrial, metalcore, nu_metal
# 7735          RnB  metal, hard_rock, heavy_metal, thrash_metal, c...
# 8960          RnB                       female_vocalists, jazz, soul
# 24119        Rock       thrash_metal, metalcore, melodic_death_metal
# 48153        Rock                                                NaN
# 48460        Rock                           indie, indie_pop, mellow
# 42607       World  rock, indie, pop, female_vocalists, singer_son...
# 49607       World                                                NaN
# 49120       World                                                NaN

# %%
# song titles in the data that are not in english

(
    df_songs
    .loc[
        df_songs
        .loc[:, "name"]
        .str.contains("[^\\d\\w\\s.?!':;-_(){},\\.#-&/-]")
    ]
)
# Out:
#                  track_id                                               name  \
# 2455   TRBGIZH128F4252D9E                                          2 + 2 = 5
# 4463   TRGHMRU128F1478067                     I Put The "Metro" In Metronome
# 6870   TRGIILN12903CE46BB                                                1+1
# 7902   TRZMLSV128F9305C8C                                          B********
# 7974   TRFRAEO128F4279C87                                    F**k the System
# 10722  TRODWHD128F92FD8BA                                             4 + 20
# 13127  TRLMIXB128EF3435DD                                              M+M's
# 14454  TRKEIVB128F930A597                            Nuthin' But a "G" Thang
# 17862  TRBZLOG12903CB78FD     I Belong To You [+Mon Coeur S'Ouvre A Ta Voix]
# 22541  TRYVOPZ128F4254176                                                 £4
# 22689  TRREPNS128F932937F                         This S*it Will Fcuk You Up
# 22927  TRFQDNW128F92E6646    My Heart Will Go On (Love Theme from "Titanic")
# 23064  TRALZTM128F92EC5F0  Because You Loved Me (Theme from "Up Close and...
# 24746  TRIEODF128E0788AA5                                   Appels + Oranjes
# 25734  TRAVISG128F932B3FB                                     艶かしき安息、躊躇いに微笑み
# 25743  TRDNGBD128F9322F40                                        孤独に死す、故に孤独。
# 25759  TRYYXFI128F932D175                                          凱歌、沈黙が眠る頃
# 25774  TRAUFHP128F933E28F                                       Nefi + Girly
# 25821  TRDEOIN128F932D171                                           我、闇とて･･･
# 27004  TRECOYH128F421C4F0                                The Devil, You + Me
# 28461  TRTHZPA128F92EB816              Barbarism Begins At Home (7" Version)
# 28653  TRLWWIM128E0789BA2                                               100°
# 29955  TREZRYL128F426700B                             The Downeaster "Alexa"
# 32167  TRFPAQP128F425FE22                                           Beauty*2
# 32296  TRBPQSK128F9308FBC                                           U + Me =
# 34955  TRNPJTP128F14A770D                                             (*Fin)
# 37610  TRPOEHO128E0788AB6                             Raindrops + Sunshowers
# 38908  TRTYSJW128F932E744                    2 + 2 = 5 (Live At Earls Court)
# 39291  TRHNVOG128F1487163                     Papua New Guinea (12" Version)
# 40158  TRTOHKH12903CB243F                       Outro: "Communion" (excerpt)
# 40180  TRMYIPB128F148A1AB                                         Puke + Cry
# 40509  TRTQIYK128F92F89E8                               Surf Solar (7" Edit)
# 40685  TRHWYBY128F92F5F8B                                           F**k You
# 41935  TRSHCCB128F92F77D9                            A "DC" Christmas Medley
# 48105  TRPJKNS128F428A861                                            1*15*96
# 48715  TRBFFHT128E078EC43                   What The F**k Is Wrong With You?
# 48841  TRAODBZ128F930772A                                          Hit + Run
# 49041  TRYYFBB12903CC5404                                     F*** you bitch
# 49434  TRZCMJX128F4273317                                 ¿Dónde Estabas Tú?
#
#                              artist              spotify_id  \
# 2455                      Radiohead  0dUSgj5UiJHY92RCuEFYcx
# 4463        Cute Is What We Aim For  718VxOgHaLU7oGS9686hg6
# 6870                        Beyoncé  0b4bcwV5QWTzgza5u1gh5C
# 7902                      Rammstein  2fKyVXrtvFkqv5lVPf1UXa
# 7974               System of a Down  0uvPnGOwcaUNT6gwJF98wL
# 10722  Crosby, Stills, Nash & Young  2jZPEeW2ynykb2GkVqpOkJ
# 13127                     blink-182  0z6VQdAqi0HjQYULMUYpBt
# 14454                       Dr. Dre  1qaZx6y94LiMy2KdhHxRTy
# 17862                          Muse  114rzL6VEy9bb3amPcY3tw
# 22541            These New Puritans  1LsQ5WkLU8ubiAz6AtMNll
# 22689                   Combichrist  2UrxdWUNCFSCiDe2Ded8NW
# 22927                   Céline Dion  08598gsRDF4RctyTY4Gxil
# 23064                   Céline Dion  0cGoe4twi12yqSoHxV0nxI
# 24746         The Smashing Pumpkins  1Gk1wuDwryqwg4Jmwingz9
# 25734                   DIR EN GREY  0PFAQlY7D7yBwJAanpChL4
# 25743                   DIR EN GREY  0dADQw6XqDlmhrUZyO6xhc
# 25759                   DIR EN GREY  1qTEroNtj9rEdrUYi8Jx3m
# 25774                   Asobi Seksu  0hE9SA9XyEvmKWBGxOJYzA
# 25821                   DIR EN GREY  2cCFXQSOgtAsj8tAHMMOVp
# 27004                   The Notwist  1iyDMFO47lfJtMzxxzdQd2
# 28461                    The Smiths  1F45jjZVMcknWbbuP7425P
# 28653               Shout Out Louds  39zN9w7I61Bc8q9QsCJXBn
# 29955                    Billy Joel  0Kc2Qh2cCLliz3v5KzuFiU
# 32167                      Ladytron  0qzZWYQBeNvwLYZtZaV28B
# 32296                     Dan Black  2f6ho9QMQRiRBuFRt7ctSD
# 34955                      Anberlin  0onRDEEaRSVJRTCrQkaV5w
# 37610         The Smashing Pumpkins  3hmprjufdcR1nYd4vHK7EI
# 38908                     Radiohead  2IYcU17nwiTVxK8yJwrTsE
# 39291    The Future Sound of London  3yHmfkhY4pIdEkmQ6DRKFE
# 40158                      Enslaved  0D1tdm73eHpcew0OnrjvSQ
# 40180                  Dinosaur Jr.  6ndCgHOVIkbqiKGPCs15fH
# 40509                  Fuck Buttons  6qFfNj3F0TPak0WJxA8DLv
# 40685          Sleeping with Sirens  0pUU0pv9bKqXGpYAvfINXK
# 41935               Destiny's Child  05ktN4x8Rp4rAJwjVIFpUM
# 48105                    The Ataris  0yrRfU971QWUF4rT3Vi3gU
# 48715                   Combichrist  5joNSDa346huRuTckNa8Ok
# 48841             Kill Memory Crash  0F1Et8CVNV5OrXFTWO4XLW
# 49041              Suicide Commando  1p90sZhCpxeXwB6rs3rnfw
# 49434               Omara Portuondo  0kM2ZjqOCikbKDigQBUVdf
#
#                                                     tags       genre  year  \
# 2455   rock, electronic, alternative, indie, alternat...        Rock  2008
# 4463                                    alternative, emo        Rock  2006
# 6870              female_vocalists, soul, rnb, beautiful         NaN  2011
# 7902                           metal, industrial, german        Rock  2009
# 7974                                     metal, nu_metal       Metal  2002
# 10722  rock, classic_rock, folk, singer_songwriter, a...        Rock  1970
# 13127                                    punk, punk_rock         NaN  2005
# 14454                                  rap, 90s, hip_hop         NaN  2005
# 17862  rock, alternative_rock, progressive_rock, soun...        Rock  2009
# 22541  electronic, alternative, british, industrial, ...        Rock  2008
# 22689                                         industrial         NaN  2005
# 22927  pop, female_vocalists, soundtrack, 90s, beautiful         NaN  2008
# 23064        pop, female_vocalists, soundtrack, pop_rock         Pop  2008
# 24746  rock, alternative, alternative_rock, 90s, amer...        Rock  1998
# 25734                                  japanese, screamo         NaN  2007
# 25743                                    metal, japanese         NaN  2005
# 25759                                    metal, japanese         NaN  2008
# 25774                                    indie, japanese        Rock  2006
# 25821                                           japanese         NaN  2008
# 27004                          electronic, indie, german        Rock  2008
# 28461                                      80s, new_wave        Rock  2011
# 28653                      indie_rock, new_wave, swedish        Rock  2005
# 29955  rock, pop, classic_rock, singer_songwriter, pi...        Rock  1997
# 32167            electronic, chillout, electro, synthpop  Electronic  2005
# 32296                electronic, indie, british, electro         NaN  2009
# 34955                  rock, alternative, emo, beautiful        Rock  2013
# 37610                     rock, alternative_rock, grunge        Rock  2000
# 38908  rock, alternative, indie, alternative_rock, am...        Rock  2003
# 39291                          electronic, chillout, idm  Electronic  1992
# 40158  metal, ambient, experimental, instrumental, bl...         NaN  2004
# 40180  rock, alternative, alternative_rock, indie_roc...        Rock  1991
# 40509             electronic, indie, experimental, noise  Electronic  2009
# 40685                                              cover         NaN  2011
# 41935                                                NaN         RnB  2001
# 48105                                                NaN         NaN  1999
# 48715                                         industrial         NaN  2007
# 48841                             electronic, industrial  Electronic  2008
# 49041                             electronic, industrial  Electronic  2006
# 49434                                                NaN       Latin  2000
#
#        duration_ms  danceability  energy  key  loudness  mode  speechiness  \
# 2455        199360         0.443   0.717    5    -5.498     0       0.0504
# 4463        206053         0.538   0.858   11    -3.862     1       0.0638
# 6870        273880         0.303   0.384    6    -7.342     1       0.0339
# 7902        254013         0.352   0.905    9    -3.792     1       0.0836
# 7974        132733         0.474   0.994    8    -1.884     1       0.1030
# 10722       126640         0.638   0.058    4   -25.243     1       0.0388
# 13127       155680         0.212   0.921    9    -6.092     1       0.0567
# 14454       230026         0.817   0.704    7    -8.336     1       0.2850
# 17862       338813         0.481   0.603    2    -6.590     1       0.0280
# 22541       133173         0.692   0.759   11    -9.216     1       0.0533
# 22689       285666         0.490   0.947    1    -5.910     1       0.0413
# 22927       280533         0.419   0.370    4    -8.637     1       0.0298
# 23064       274573         0.612   0.532    1    -6.873     1       0.0339
# 24746       215693         0.446   0.980    8    -7.882     1       0.0555
# 25734       277706         0.586   0.771    5    -6.157     0       0.0354
# 25743       205800         0.390   0.791    6    -7.950     0       0.0431
# 25759       262826         0.504   0.978    6    -5.199     0       0.0816
# 25774       277733         0.327   0.799    7    -6.175     1       0.0432
# 25821       423253         0.531   0.815    8    -6.928     0       0.0376
# 27004       219053         0.542   0.243    9   -13.768     1       0.0330
# 28461       231493         0.506   0.913    1    -3.622     0       0.0432
# 28653       228746         0.355   0.954    7    -2.790     1       0.0734
# 29955       222840         0.400   0.812    9    -5.783     0       0.0386
# 32167       263573         0.735   0.611    6    -8.546     0       0.0268
# 32296       189226         0.726   0.713    9    -6.884     1       0.0893
# 34955       524400         0.213   0.704    4    -6.157     1       0.0347
# 37610       279533         0.444   0.959    1    -6.439     1       0.0464
# 38908       215266         0.306   0.817    5    -8.073     0       0.0561
# 39291       302626         0.595   0.716    8   -12.563     1       0.0428
# 40158        56600         0.219   0.287    6   -18.131     1       0.0343
# 40180       266533         0.388   0.941    0    -7.034     1       0.0423
# 40509       221533         0.413   0.901    7    -7.410     1       0.0395
# 40685       213146         0.462   0.961    1    -3.414     0       0.0897
# 41935       239360         0.763   0.822    4    -3.950     0       0.1570
# 48105       234466         0.268   0.918    0    -5.112     1       0.0467
# 48715       300000         0.526   0.935    1    -5.886     1       0.0510
# 48841       314297         0.605   0.875    0    -4.257     0       0.0482
# 49041       359160         0.459   0.936    0    -7.533     1       0.0319
# 49434       223133         0.732   0.314    0   -11.633     0       0.0532
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 2455       0.182000          0.000051    0.3450   0.3860  149.582
# 4463       0.085200          0.000000    0.2580   0.7060  149.971
# 6870       0.381000          0.000005    0.0661   0.2610   63.345
# 7902       0.000895          0.218000    0.1810   0.3270  141.016
# 7974       0.002160          0.126000    0.3140   0.8470  171.433
# 10722      0.928000          0.079000    0.1130   0.1260  140.964
# 13127      0.000054          0.003990    0.0669   0.6800  159.629
# 14454      0.009390          0.000000    0.0850   0.6800   94.627
# 17862      0.166000          0.032100    0.1090   0.2130  105.974
# 22541      0.052200          0.012900    0.4630   0.2560   99.988
# 22689      0.000005          0.734000    0.3620   0.2150  120.019
# 22927      0.716000          0.000003    0.1810   0.0382   98.982
# 23064      0.321000          0.000000    0.0995   0.1820  119.914
# 24746      0.004080          0.890000    0.0923   0.3730  112.824
# 25734      0.004200          0.110000    0.0384   0.3430   89.041
# 25743      0.000021          0.072700    0.0589   0.3170  132.039
# 25759      0.000012          0.775000    0.1490   0.2810  113.903
# 25774      0.000319          0.660000    0.3580   0.4030  163.258
# 25821      0.021900          0.395000    0.4580   0.2970  104.961
# 27004      0.746000          0.786000    0.1110   0.2450  139.838
# 28461      0.059400          0.003970    0.5290   0.7640  125.655
# 28653      0.001060          0.000048    0.2940   0.5700  155.580
# 29955      0.117000          0.000000    0.1260   0.6070   88.971
# 32167      0.171000          0.192000    0.1110   0.6830  120.317
# 32296      0.019800          0.009050    0.1510   0.5170  121.960
# 34955      0.208000          0.001520    0.0914   0.1840  163.941
# 37610      0.000030          0.809000    0.1110   0.6360  124.936
# 38908      0.055900          0.000658    0.3570   0.3490  148.168
# 39291      0.000486          0.885000    0.1620   0.6530  124.990
# 40158      0.811000          0.913000    0.1170   0.0579   82.136
# 40180      0.000362          0.000079    0.0779   0.5940  104.246
# 40509      0.000002          0.738000    0.3530   0.3690  129.997
# 40685      0.000859          0.000000    0.2190   0.4790  136.018
# 41935      0.054800          0.000000    0.2340   0.7710   93.738
# 48105      0.000149          0.000212    0.0729   0.7660  165.014
# 48715      0.000498          0.000023    0.1820   0.1530  119.988
# 48841      0.000041          0.644000    0.0822   0.8630  117.998
# 49041      0.000307          0.931000    0.3400   0.4250  147.995
# 49434      0.727000          0.005280    0.2680   0.6360  116.968
#
#        time_signature
# 2455                4
# 4463                4
# 6870                5
# 7902                3
# 7974                4
# 10722               4
# 13127               4
# 14454               4
# 17862               4
# 22541               4
# 22689               4
# 22927               1
# 23064               4
# 24746               4
# 25734               3
# 25743               4
# 25759               4
# 25774               4
# 25821               4
# 27004               4
# 28461               4
# 28653               4
# 29955               4
# 32167               4
# 32296               4
# 34955               3
# 37610               4
# 38908               4
# 39291               4
# 40158               5
# 40180               4
# 40509               4
# 40685               4
# 41935               4
# 48105               4
# 48715               4
# 48841               4
# 49041               4
# 49434               4

# %%
# artists in the data that are not in english

df_songs[df_songs.loc[:, "artist"].str.contains("[^\d\w\s.?!':;-_\(\)\{\},\.#-+&\/\-\"]")]
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_36420\2648081126.py:3: SyntaxWarning: invalid escape sequence '\d'
#   df_songs[df_songs.loc[:, "artist"].str.contains("[^\d\w\s.?!':;-_\(\)\{\},\.#-+&\/\-\"]")]
#                  track_id                    name                 artist  \
# 25657  TRUOKRP128F9306B97         DAYBREAK'S BELL          L'Arc~en~Ciel
# 25688  TRYYZGB128F9306B92  MY HEART DRAWS A DREAM          L'Arc~en~Ciel
# 25696  TRYAFFS128F425E71A          Seventh Heaven          L'Arc~en~Ciel
# 25704  TRZBUIY128F9306B9D              Hurry Xmas          L'Arc~en~Ciel
# 25715  TRDLCHM128F427F235    Spirit dreams inside          L'Arc~en~Ciel
# 25763  TRKTCEP128F9306B91             Pretty girl          L'Arc~en~Ciel
# 25788  TRMDISG128EF341CBC               Lover Boy          L'Arc~en~Ciel
# 25790  TRHNIIF128F42884A7                   TRUST          L'Arc~en~Ciel
# 25799  TRMZMPL128F1490F27                    Niji          L'Arc~en~Ciel
# 25800  TRANWBU128F42717D4                 My Dear          L'Arc~en~Ciel
# 25801  TRMIJFJ128F92E4322            Feeling Fine          L'Arc~en~Ciel
# 25806  TRBDBAO128F9306B96        ALONE EN LA VIDA          L'Arc~en~Ciel
# 25818  TRFEIRU128F9306B95                  spiral          L'Arc~en~Ciel
# 25819  TRJLZNV128F9306B9A          THE BLACK ROSE          L'Arc~en~Ciel
# 25849  TRYKCOS128F9325E0B                    fate          L'Arc~en~Ciel
# 25869  TRUDYAW12903C93A7F                   SHINE          L'Arc~en~Ciel
# 25888  TRIQSUH128F92D764C            Perfect Blue          L'Arc~en~Ciel
# 25928  TRZCMQL128F1455265                    Dune          L'Arc~en~Ciel
# 25951  TREMQTE128F422B68B               Fare Well          L'Arc~en~Ciel
# 31918  TRABBEX128F9322F79                  Twelve      ¡Forward, Russia!
# 37226  TRKNDSE128F9323892               Pirouette  ::M∆DE::IN::HEIGHTS::
# 43615  TRFNXGY128F9344550           Promised land          L'Arc~en~Ciel
# 43637  TRUKJBV128F9306B93               Sunadokei          L'Arc~en~Ciel
# 43657  TREJKIJ128F9306B9C         Yuki no Ashiato          L'Arc~en~Ciel
#
#                    spotify_id                          tags  genre  year  \
# 25657  0f6N93Iqa1jIGY87ckKe8h               japanese, j_pop    NaN  2007
# 25688  0K1VcVuws8cBEOS8bb8Svo               japanese, j_pop    NaN  2007
# 25696  0vc0kp9kYeqLCoDOKFYESL               japanese, j_pop    NaN  2007
# 25704  0NMWlIwjGldOgbABHTYx82               japanese, j_pop   Rock  2007
# 25715  0hyTPlLk6MWOGiKFstN0S2                      japanese    NaN  2002
# 25763  0QUESFm42vSLGffjwud4jl               japanese, j_pop   Rock  2007
# 25788  69Gd7FRSCuB4X7D7gDOdhz                      japanese    NaN  2004
# 25790  5ROfpAhDOiDkyn17SNDtAG                      japanese    NaN  2005
# 25799  1AhmwzPwhatp999J4Ky9nH               japanese, j_pop    NaN  1998
# 25800  12UBEdmkCBXtnbnQEvdHWp                      japanese    NaN  2005
# 25801  1ZP6q6dIr4UWWFNN8zE6dM                      japanese    NaN  2004
# 25806  1RxDFC0T1i9xLu8gZaTWdq                      japanese    NaN  2007
# 25818  08k0iuV0hUOn8J30ll2vIX               japanese, j_pop    NaN  2007
# 25819  1KgJMhzDqFC0GZIoGZ134N                      japanese    NaN  2007
# 25849  5FebumWFsOoJZkOUCkjFWB               japanese, j_pop    NaN  1998
# 25869  3rPb9SPwDeCMb9nvd176MB               japanese, j_pop    NaN  2012
# 25888  5ZY7CEwpe9Gt3eiW1QSmTf               japanese, j_pop    NaN  1999
# 25928  1FW89w3bO1BslS0nRlckSK                      japanese  World  2007
# 25951  315j6UqGrFndKgUsFVcXpO                      japanese    NaN  1996
# 31918  1eDKl9CB40OcfKM88GSEJw  indie, indie_rock, post_punk    NaN  2006
# 37226  50yLYrB1YG7qhpO3bIbIeQ           downtempo, synthpop    NaN  2014
# 43615  4im5jqHZ2Ykozz0xK5PamI               japanese, j_pop   Jazz  1998
# 43637  0SXfBToKaQ6k4dlT3OeMLh               japanese, j_pop    NaN  2007
# 43657  0BgG9KWaECzTpK6myjPvtJ               japanese, j_pop    NaN  2007
#
#        duration_ms  danceability  energy  key  loudness  mode  speechiness  \
# 25657       251653         0.442   0.939    7    -4.032     1       0.0432
# 25688       256826         0.449   0.812    2    -4.105     1       0.0332
# 25696       301373         0.488   0.963    9    -3.486     1       0.0532
# 25704       289133         0.447   0.869    0    -3.362     1       0.0508
# 25715       224013         0.510   0.959    9    -4.793     1       0.0548
# 25763       197866         0.373   0.954    0    -3.024     1       0.0777
# 25788       285026         0.428   0.977    4    -4.600     0       0.0701
# 25790       269066         0.507   0.895    2    -5.892     1       0.0432
# 25799       305600         0.521   0.706    2    -6.931     1       0.0284
# 25800       309826         0.464   0.804    8    -5.762     0       0.0320
# 25801       256933         0.485   0.956    2    -3.164     1       0.0429
# 25806       312160         0.485   0.878    9    -4.277     0       0.0326
# 25818       241066         0.513   0.931    5    -4.531     0       0.0336
# 25819       218186         0.462   0.941    4    -3.805     0       0.0777
# 25849       339466         0.531   0.893   11    -8.397     0       0.0364
# 25869       244933         0.466   0.895    2    -3.006     1       0.0390
# 25888       227666         0.601   0.652    0    -5.818     1       0.0260
# 25928       304500         0.580   0.933   11    -4.214     0       0.0443
# 25951       297026         0.444   0.577    0    -7.911     1       0.0284
# 31918       134453         0.406   0.956   11    -3.452     0       0.0737
# 37226       250937         0.783   0.383    0   -10.312     1       0.0521
# 43615       269666         0.533   0.952    9    -6.747     0       0.0745
# 43637       275146         0.475   0.666    7    -4.995     1       0.0326
# 43657       287613         0.371   0.615    7    -6.292     1       0.0317
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 25657      0.001010          0.000282    0.3040    0.780  156.138
# 25688      0.000732          0.000000    0.1130    0.287  131.850
# 25696      0.000381          0.000000    0.7340    0.795  129.963
# 25704      0.043600          0.000001    0.1350    0.562  116.043
# 25715      0.000194          0.002000    0.1950    0.693  118.017
# 25763      0.001360          0.000000    0.0548    0.695  176.037
# 25788      0.003850          0.001320    0.1630    0.504  152.023
# 25790      0.002160          0.002600    0.0745    0.393   95.965
# 25799      0.001310          0.000206    0.3610    0.534   93.020
# 25800      0.198000          0.006470    0.1360    0.362  112.013
# 25801      0.004640          0.000007    0.3880    0.833  145.075
# 25806      0.065600          0.001740    0.2370    0.591  100.043
# 25818      0.001430          0.000000    0.0812    0.782   91.008
# 25819      0.004110          0.000022    0.0663    0.407   95.042
# 25849      0.000844          0.000058    0.4750    0.554  106.045
# 25869      0.005340          0.000000    0.0904    0.518  139.036
# 25888      0.081200          0.000026    0.1110    0.499  120.908
# 25928      0.001710          0.000074    0.1530    0.675  109.426
# 25951      0.003590          0.001600    0.5100    0.239   85.963
# 31918      0.000344          0.000221    0.1570    0.813  165.209
# 37226      0.702000          0.065200    0.0755    0.514  129.929
# 43615      0.000320          0.008880    0.6580    0.440  121.979
# 43637      0.023600          0.000002    0.1540    0.340  113.939
# 43657      0.112000          0.000000    0.3730    0.204   69.981
#
#        time_signature
# 25657               4
# 25688               4
# 25696               4
# 25704               4
# 25715               4
# 25763               4
# 25788               4
# 25790               4
# 25799               4
# 25800               4
# 25801               4
# 25806               4
# 25818               4
# 25819               4
# 25849               4
# 25869               4
# 25888               4
# 25928               4
# 25951               4
# 31918               1
# 37226               4
# 43615               4
# 43637               4
# 43657               4

# %%
df_songs['tags'][0]
# Out:
# 'rock, alternative, indie, alternative_rock, indie_rock, 00s'

# %%
all_tags=[]

for tags in df_songs['tags'].dropna().str.replace(" ", ""). str.split(", "):
    all_tags.extend(tags)

#ye tags ko ek list mai lekar aata hai, disrespective ki ek song mai kyi tags ho sakte hai,isiliye first we remove space pop, indi= pop,indi 
#fir we split it on basis of ',' and it flattens all tag in one list,

# %%
print("The number of unique tags are ",len(set(all_tags)))
# Out:
# The number of unique tags are  20054

# %%
set(all_tags)
# Out:
# {'electronic,ambient,techno',
#  'punk,cover,ska',
#  'instrumental,chillout,rap,hip_hop,chill',
#  'classic_rock,soundtrack,70s,60s,oldies',
#  'death_metal,industrial,gothic_metal,gothic',
#  'electronic,hip_hop,trip_hop,rnb',
#  'electronic,avant_garde',
#  'electronic,pop,dance,chillout,new_wave,american,indie_pop,synthpop,chill',
#  'rock,indie,indie_rock,british,piano,indie_pop,love,beautiful,britpop,mellow',
#  'indie,downtempo,swedish',
#  'pop,80s,new_wave',
#  'electronic,female_vocalists,ambient,swedish',
#  'rock,experimental,punk,punk_rock,70s,grunge',
#  'rock,classic_rock,blues,oldies,guitar',
#  'alternative,indie,alternative_rock,experimental,guitar,noise',
#  'electronic,alternative,indie,pop,british,soul',
#  'folk,acoustic,beautiful,mellow',
#  'oldies,guitar',
#  'rock,pop,female_vocalists,90s,britpop,pop_rock',
#  'rock,alternative,alternative_rock,90s,american,grunge',
#  'rock,pop,soundtrack,pop_rock',
#  'indie,folk,singer_songwriter,psychedelic',
#  'electronic,alternative,indie,gothic',
#  'psychedelic,doom_metal',
#  'indie,female_vocalists,folk,singer_songwriter,piano,mellow',
#  'rock,alternative_rock,rap,punk_rock,hip_hop',
#  'indie,pop,female_vocalists',
#  'rock,female_vocalists,metal,american,gothic_metal,gothic,symphonic_metal,nu_metal',
#  'indie,folk,singer_songwriter,acoustic,love,mellow',
#  'indie,folk,singer_songwriter,chillout,soundtrack,acoustic,love,beautiful,mellow,chill',
#  'electronic,house,techno',
#  'electronic,alternative,pop,trance',
#  'acoustic,progressive_metal',
#  'indie,alternative_rock,experimental,indie_rock,80s,psychedelic,post_punk,grunge,noise',
#  'indie,indie_rock,british,post_punk',
#  'rock,classic_rock,british,blues,70s',
#  'electronic,alternative,indie,experimental,post_rock,french,britpop,lounge',
#  'alternative_rock,hard_rock,heavy_metal,90s,grunge',
#  'progressive_rock,industrial,progressive_metal',
#  'rock,electronic,alternative,indie,alternative_rock,experimental,punk,indie_rock,singer_songwriter,90s',
#  'rock,alternative,indie,pop,alternative_rock,indie_rock,american,indie_pop',
#  'rock,indie,pop,indie_rock',
#  'electronic,experimental,instrumental,psychedelic,trance,techno,00s,noise',
#  'electronic,alternative,indie,pop,indie_rock,chillout,indie_pop,mellow,chill',
#  'female_vocalists,jazz,blues,acoustic',
#  'indie,indie_rock,psychedelic,indie_pop,psychedelic_rock',
#  'electronic,dance,trip_hop,techno',
#  'rock,electronic,alternative,pop,dance,piano,male_vocalists,love,beautiful,00s,mellow',
#  'electronic,pop,female_vocalists,dance,american',
#  'instrumental,death_metal,thrash_metal,melodic_death_metal',
#  'pop,female_vocalists,classic_rock,80s,70s,oldies',
#  'metal,death_metal,progressive_metal,melodic_death_metal,french',
#  'acoustic,emo,post_hardcore,screamo',
#  'rock,alternative,indie,alternative_rock,experimental,punk,indie_rock,progressive_rock,punk_rock,acoustic,american,male_vocalists,emo,love,beautiful',
#  'indie,folk,acoustic,guitar,cover,lounge',
#  'rock,pop,female_vocalists,classic_rock,piano,70s,pop_rock',
#  'rock,classic_rock,folk,progressive_rock,70s',
#  'indie,indie_pop,mellow',
#  'pop,dance,rnb,male_vocalists',
#  'electronic,ambient,instrumental,chillout,trip_hop,downtempo,french,lounge,chill',
#  'industrial',
#  'electronic,indie,ambient,chillout,trip_hop,downtempo,chill',
#  'black_metal,heavy_metal,gothic_metal,cover',
#  'electronic,ambient,techno,noise',
#  'rock,alternative,alternative_rock,punk,emo,screamo,pop_rock',
#  'electronic,ambient,experimental,chillout,psychedelic,electro,downtempo,idm',
#  'female_vocalists,jazz,soundtrack,oldies,love',
#  'electronic,alternative,pop,japanese,techno',
#  'alternative,female_vocalists,jazz,singer_songwriter,chillout,polish',
#  'pop,electro,french',
#  'rock,indie_rock,chill',
#  'indie,indie_rock,dance,funk,new_wave,electro',
#  'rock,alternative,indie,80s,british,soundtrack,new_wave,post_punk',
#  'electronic,alternative,indie,experimental,indie_rock,singer_songwriter,rap,hip_hop,funk,electro,00s',
#  'pop,80s,soundtrack,90s,love,cover',
#  'rock,alternative,pop,soundtrack,male_vocalists',
#  'soul,funk,70s,cover',
#  'alternative,britpop',
#  'electronic,chillout,trip_hop,french,lounge',
#  'metal,psychedelic',
#  'rock,classic_rock,instrumental,60s',
#  'alternative_rock,ska',
#  'experimental,indie_rock,instrumental,post_rock',
#  'experimental,industrial,german,dark_ambient,noise,avant_garde',
#  'rock,pop,female_vocalists,singer_songwriter,beautiful,00s,pop_rock',
#  'rock,alternative,metal,alternative_rock,punk,hardcore,punk_rock,emo,post_hardcore',
#  'rock,alternative,pop,female_vocalists,alternative_rock,punk,indie_rock,punk_rock,emo,pop_rock',
#  'dance,90s,german,techno',
#  'alternative,indie,alternative_rock,instrumental,emo',
#  'metal,instrumental,heavy_metal,classical,cover,symphonic_metal',
#  'new_wave,cover',
#  'rock,classic_rock,blues,psychedelic_rock,blues_rock',
#  'rock,alternative,indie,metal,alternative_rock,post_hardcore',
#  'female_vocalists,jazz,soul,chillout,funk',
#  'rock,classic_rock,hard_rock,80s,heavy_metal,love',
#  'funk,reggae,trip_hop',
#  'rock,punk,punk_rock,emo,00s',
#  'rock,indie,alternative_rock,experimental,punk,indie_rock,hardcore,post_punk',
#  'classic_rock,singer_songwriter,80s,soundtrack,male_vocalists,love,beautiful,cover,mellow',
#  'dance,90s,trance,techno',
#  'post_rock,00s',
#  'rock,electronic,alternative,indie,pop,indie_rock,indie_pop,french',
#  'electronic,chillout,trip_hop,idm,lounge',
#  'rock,electronic,pop,female_vocalists,metal,classic_rock,ambient,punk,black_metal,dance,80s,death_metal,heavy_metal,hardcore,british,soul,classical,rap,90s,metalcore,japanese,hip_hop,funk,trance,house,techno,70s,60s,melodic_death_metal,power_metal,emo,post_hardcore,beautiful,french,gothic_metal,russian,noise,swedish,screamo,symphonic_metal,grindcore,nu_metal,j_pop,polish,new_age',
#  'chillout,lounge,drum_and_bass',
#  'rock,alternative,female_vocalists,experimental,singer_songwriter,house,piano,american',
#  'rock,alternative_rock,hard_rock,progressive_rock,70s,male_vocalists,guitar,blues_rock',
#  'metal,thrash_metal,doom_metal',
#  'female_vocalists,classical,love,new_age',
#  'electronic,indie,british,soul,hip_hop,funk,synthpop',
#  'female_vocalists,progressive_metal,doom_metal,gothic_metal,gothic,dark_ambient',
#  'rock,classic_rock,american,60s,country,oldies',
#  'blues,70s,guitar,blues_rock',
#  'pop,female_vocalists,dance,soul,hip_hop,rnb',
#  'metal,progressive_metal,melodic_death_metal,power_metal',
#  'rock,alternative,alternative_rock,acoustic,american,grunge,mellow',
#  'indie,folk,hip_hop',
#  '60s,psychedelic_rock',
#  'folk,post_rock,beautiful,french',
#  'soul,funk,rnb,lounge',
#  'electronic,alternative,indie,pop,80s,indie_pop,synthpop',
#  'electronic,alternative,alternative_rock,singer_songwriter,american,trip_hop,male_vocalists,beautiful,00s,mellow,chill',
#  'female_vocalists,soul,60s,oldies,love',
#  'rock,pop,female_vocalists,singer_songwriter,guitar,pop_rock',
#  'electronic,female_vocalists,soundtrack,electro,00s',
#  'electronic,ambient,experimental,chillout,electro,downtempo,idm',
#  'rock,industrial,gothic_metal,cover',
#  'rock,alternative,alternative_rock,indie_rock,emo,post_hardcore,screamo',
#  'alternative,indie,indie_rock,british,00s',
#  'rock,electronic,alternative,indie,female_vocalists,alternative_rock,singer_songwriter,90s,trip_hop,chill',
#  'indie,folk,indie_rock,singer_songwriter,chillout,indie_pop,pop_rock',
#  'rock,electronic,alternative,indie,pop,female_vocalists,alternative_rock,experimental,folk,punk,indie_rock,singer_songwriter,dance,soul,chillout,rap,soundtrack,punk_rock,acoustic,psychedelic,post_rock,hip_hop,funk,new_wave,house,reggae,trip_hop,techno,electro,country,downtempo,synthpop,idm,cover,chill,ska',
#  'rock,classic_rock,folk,70s,60s,country,oldies,psychedelic_rock',
#  'indie,cover',
#  'rock,indie,classic_rock,indie_rock,00s,blues_rock',
#  'electronic,ambient,chillout,german,downtempo',
#  'experimental,instrumental,post_rock',
#  'ambient,soundtrack,trance,new_age',
#  'progressive_rock,hardcore,post_punk,post_hardcore',
#  'jazz,ambient,funk,downtempo,idm',
#  'electronic,ambient,instrumental,progressive_rock,new_age',
#  'folk,punk,hardcore,punk_rock,beautiful,cover',
#  'electronic,indie,experimental,electro,00s',
#  'electronic,female_vocalists,house',
#  'chillout,french,cover,lounge',
#  'electronic,indie,female_vocalists,indie_pop,synthpop',
#  'electronic,jazz,ambient,chillout,downtempo,guitar,chill,new_age',
#  'rock,indie,folk,cover',
#  'metal,german,power_metal,cover',
#  'pop,80s,funk,new_wave',
#  'rock,alternative_rock,psychedelic,grunge',
#  'indie,folk,british,indie_pop,beautiful,00s',
#  'techno,drum_and_bass',
#  'rock,classic_rock,psychedelic,60s,psychedelic_rock',
#  'death_metal,doom_metal,gothic_metal,gothic',
#  'rock,alternative,progressive_rock,psychedelic,japanese,progressive_metal,funk,psychedelic_rock',
#  'rock,alternative,80s',
#  'electronic,ambient,british,chillout,downtempo',
#  'electronic,alternative,female_vocalists,experimental,singer_songwriter,beautiful,avant_garde',
#  'metal,melodic_death_metal,power_metal,swedish,symphonic_metal',
#  'classical,german,gothic_metal,symphonic_metal',
#  'rock,alternative,indie,indie_rock,blues,90s,american,indie_pop,emo',
#  'rock,new_wave,male_vocalists',
#  'rock,alternative,female_vocalists,alternative_rock,hard_rock,emo,beautiful',
#  'rock,classic_rock,singer_songwriter,80s',
#  'alternative,pop,female_vocalists,british,new_wave,synthpop',
#  'alternative,indie,pop,folk,indie_rock,indie_pop',
#  'soul,chillout,rnb',
#  'soul,funk,trip_hop',
#  'hardcore,metalcore,emo,post_hardcore,beautiful,screamo',
#  'industrial,synthpop,gothic',
#  'indie,indie_rock,emo,mellow',
#  'rock,alternative,folk,polish',
#  'metal,instrumental,classical,symphonic_metal',
#  'rock,pop,singer_songwriter,acoustic,piano,male_vocalists,love,mellow,pop_rock',
#  'pop,dance,trance,french',
#  'dance,80s,house,techno',
#  'hardcore,soundtrack,emo,post_hardcore,screamo',
#  'rock,female_vocalists,alternative_rock,indie_rock,blues_rock',
#  'electronic,jazz,ambient,psychedelic,funk,trip_hop,idm',
#  'experimental,hardcore',
#  'soul,90s,hip_hop,rnb,male_vocalists,love',
#  'rock,alternative,indie,folk,indie_rock,00s,mellow',
#  'classic_rock,blues,60s,psychedelic_rock,blues_rock',
#  'alternative,indie,new_wave,male_vocalists',
#  'electronic,alternative,indie,pop,female_vocalists,ambient,experimental,chillout,90s,trip_hop,love,beautiful,mellow,chill',
#  'rock,progressive_rock,blues',
#  'electronic,french',
#  'electronic,chillout,trip_hop,electro,downtempo,french,lounge,chill',
#  'indie,ska',
#  'rock,alternative,indie,alternative_rock,punk,indie_rock,instrumental,80s,90s,american,guitar,cover',
#  'pop,80s,soul,american',
#  'rock,classic_rock,experimental,blues,psychedelic,60s,psychedelic_rock,avant_garde',
#  'pop,hip_hop,drum_and_bass',
#  'metal,death_metal,gothic_metal',
#  'metal,punk,russian,ska',
#  'downtempo,synthpop',
#  'metal,death_metal,thrash_metal,melodic_death_metal',
#  'rock,alternative_rock,punk,punk_rock,american,00s',
#  'rock,alternative,indie,folk,piano,indie_pop,beautiful,mellow',
#  'rock,drum_and_bass',
#  'rock,alternative,indie,singer_songwriter,blues,american,male_vocalists,guitar',
#  'electronic,80s,british,industrial,90s,new_wave,downtempo,synthpop',
#  'black_metal,gothic_metal,cover,symphonic_metal',
#  'alternative,french',
#  'folk,singer_songwriter,acoustic,70s,country,oldies',
#  'metal,black_metal,death_metal,thrash_metal,german,melodic_death_metal,power_metal',
#  'indie,female_vocalists,folk,acoustic,indie_pop,beautiful',
#  'electronic,ambient,post_rock,post_punk,electro,synthpop',
#  'soundtrack,japanese,j_pop',
#  'electronic,ambient,funk,idm',
#  'electronic,chillout,electro,downtempo,idm,mellow,lounge',
#  'female_vocalists,jazz,funk',
#  'indie,ambient,experimental,folk,instrumental,singer_songwriter',
#  'experimental,post_punk,noise,avant_garde',
#  'heavy_metal,power_metal,cover',
#  'instrumental,chillout,soundtrack',
#  'hard_rock,heavy_metal,thrash_metal',
#  'rnb,downtempo,male_vocalists',
#  'british,noise',
#  'rock,alternative,indie,folk,singer_songwriter,acoustic,american,male_vocalists,00s',
#  'alternative,female_vocalists,singer_songwriter,80s,progressive_rock',
#  'electronic,alternative,dance,industrial,techno',
#  'female_vocalists,jazz,chillout,polish',
#  'industrial,grindcore',
#  'chillout,trance,lounge',
#  'punk,80s,punk_rock,new_wave,post_punk',
#  'soul,funk,piano',
#  'rock,alternative,alternative_rock,jazz,acoustic,country,ska',
#  'rock,alternative,indie,pop,singer_songwriter,british,soul,chillout,acoustic,male_vocalists,love,beautiful,mellow',
#  'electronic,indie,female_vocalists,hardcore,psychedelic,trip_hop,electro,indie_pop,downtempo',
#  'experimental,folk,indie_rock,psychedelic,indie_pop,beautiful,00s,guitar',
#  'female_vocalists,singer_songwriter,soul,acoustic,reggae',
#  'rock,alternative,female_vocalists,metal,hard_rock',
#  'electronic,female_vocalists,trip_hop,french,lounge,pop_rock',
#  'electronic,chillout,french,lounge',
#  'alternative,jazz,singer_songwriter,blues',
#  'rock,electronic,alternative,indie,indie_rock,noise',
#  'chillout,funk,trip_hop,lounge',
#  'rock,classic_rock,punk,hard_rock,60s',
#  'indie_rock,piano',
#  'alternative,female_vocalists,psychedelic,mellow',
#  'folk,acoustic,60s',
#  'noise,screamo,grindcore',
#  'metal,black_metal,heavy_metal,thrash_metal,grindcore',
#  'rock,alternative,indie_rock,emo',
#  'rock,alternative,indie,alternative_rock,indie_rock,dance,80s,british,90s,funk,britpop',
#  'metal,heavy_metal,power_metal',
#  'indie,blues,cover,mellow',
#  'rock,alternative,indie,pop,punk,indie_rock,singer_songwriter,soul,german,hip_hop,techno',
#  'indie,experimental,chill',
#  'electronic,experimental,techno,electro,idm,drum_and_bass',
#  'alternative,metal,hard_rock,nu_metal',
#  'metal,punk,industrial,techno,grunge,gothic',
#  'rock,alternative,alternative_rock,hard_rock,heavy_metal,male_vocalists,grunge',
#  'folk,indie_rock,psychedelic',
#  'rock,alternative,indie,indie_rock,soul,blues,psychedelic,american,psychedelic_rock,chill,blues_rock',
#  'electronic,experimental,industrial,techno,electro,idm,drum_and_bass',
#  'alternative,piano,male_vocalists,emo,love,beautiful,mellow,chill',
#  'rock,alternative,indie,metal,alternative_rock,90s,grunge',
#  'pop,soul,hip_hop,american,rnb,lounge',
#  'electronic,trance,house,techno,cover',
#  'metal,instrumental,heavy_metal,german,power_metal',
#  'rock,alternative,indie,alternative_rock,indie_rock,grunge,gothic',
#  'rock,alternative,indie,alternative_rock,punk,90s,american',
#  'alternative,indie,alternative_rock,indie_rock,grunge',
#  'instrumental,90s,post_rock',
#  'electronic,jazz,chillout,downtempo,lounge',
#  'electronic,instrumental,chillout,psychedelic,lounge',
#  'rock,alternative,indie,alternative_rock,indie_rock,american,indie_pop,00s',
#  'electronic,house,downtempo,lounge',
#  'rock,electronic,alternative,indie,pop,female_vocalists,alternative_rock,folk,punk,indie_rock,singer_songwriter,dance,soul,rap,punk_rock,acoustic,hip_hop,funk,new_wave,house,reggae,trip_hop,indie_pop,downtempo,guitar,idm,cover,chill',
#  'death_metal,industrial',
#  'electronic,german,idm,ska',
#  'alternative,punk,punk_rock,90s',
#  'experimental,hardcore,noise',
#  'female_vocalists,piano,beautiful',
#  'rock,classic_rock,folk,singer_songwriter,acoustic,60s,oldies',
#  'pop,soul,70s,love',
#  'reggae,male_vocalists',
#  'metal,death_metal,hardcore,thrash_metal,metalcore,grindcore',
#  'rap,hip_hop,piano',
#  'indie,singer_songwriter,acoustic,chill',
#  'rock,alternative,indie,alternative_rock,experimental,indie_rock,emo,love,beautiful',
#  'indie,experimental,post_rock,post_punk,noise',
#  'indie,ambient,experimental,psychedelic',
#  'electronic,indie,pop,dance,techno',
#  'funk,reggae',
#  'electronic,indie,ambient,experimental,instrumental,british,soundtrack,noise',
#  'dark_ambient,noise',
#  'rock,alternative,indie,folk,indie_rock,acoustic,beautiful,mellow',
#  'pop,dance,rap,hip_hop,reggae,rnb,male_vocalists',
#  'rock,alternative,indie,indie_rock,psychedelic_rock,00s',
#  'electronic,american,indie_pop,synthpop',
#  'rock,folk,singer_songwriter,blues,oldies',
#  'electronic,alternative,pop,ambient,dance,chillout,techno',
#  'alternative,pop,instrumental,french',
#  'metal,heavy_metal,power_metal,symphonic_metal',
#  'punk,hard_rock,punk_rock,90s',
#  'rock,indie,alternative_rock,indie_rock,post_rock,post_hardcore',
#  'classic_rock,60s,oldies,psychedelic_rock,cover',
#  'rock,indie,indie_rock,psychedelic,psychedelic_rock,00s',
#  'pop,female_vocalists,soul,piano',
#  'singer_songwriter,soul,britpop',
#  'punk,hardcore,punk_rock,00s,ska',
#  'electronic,ambient,chillout,classical',
#  'rock,alternative,metal,alternative_rock,hard_rock,00s,grunge',
#  'electronic,ambient,industrial,noise',
#  'alternative,folk,acoustic,cover',
#  'rock,female_vocalists,classic_rock,hard_rock,80s,cover',
#  'electronic,indie,pop,dance,indie_pop,male_vocalists,00s',
#  'rock,classic_rock,80s,progressive_rock,psychedelic,psychedelic_rock',
#  'rock,alternative,indie,pop,alternative_rock,indie_rock,british,love,beautiful,00s,britpop,mellow,chill',
#  'jazz,singer_songwriter,british,piano,mellow,chill',
#  'rock,punk,punk_rock,cover,ska',
#  'rock,classic_rock,folk,60s,country,oldies',
#  'experimental,post_hardcore,noise,grindcore',
#  'soul,funk,70s,oldies',
#  'electronic,pop,female_vocalists,dance,house',
#  'instrumental,soul,funk,60s',
#  'folk,singer_songwriter,chillout,lounge',
#  'rock,pop,female_vocalists,soundtrack,country,guitar',
#  'indie,folk,singer_songwriter,indie_pop',
#  'rock,indie,alternative_rock,indie_rock,british,90s,britpop',
#  'acoustic,post_rock',
#  'electronic,ambient,chillout,trip_hop,downtempo,chill',
#  'pop,black_metal,japanese,power_metal,emo,gothic_metal,symphonic_metal,j_pop',
#  'death_metal,polish',
#  'soul,blues,60s,oldies',
#  'rock,electronic,alternative,indie,alternative_rock,experimental,indie_rock,british,00s,britpop',
#  'pop,female_vocalists,jazz,blues,90s,oldies',
#  'indie,folk,indie_rock,acoustic,indie_pop,beautiful,chill',
#  'rock,alternative,alternative_rock,80s,psychedelic,post_punk,grunge',
#  'rock,alternative,indie,folk,country',
#  'electronic,ambient,instrumental,chillout,post_rock,american,trip_hop,love,mellow,chill',
#  'metal,death_metal,industrial,thrash_metal,progressive_metal,melodic_death_metal',
#  'indie_rock,punk_rock,swedish',
#  'alternative,indie,experimental,indie_rock,progressive_rock,funk',
#  'electronic,indie,emo',
#  'rock,alternative,indie,alternative_rock,indie_rock,british',
#  'soul,blues,psychedelic,blues_rock',
#  'rock,pop,indie_pop,male_vocalists,guitar',
#  'electronic,pop,dance,soundtrack,90s,funk',
#  'indie,pop,folk,indie_rock,singer_songwriter,acoustic,mellow',
#  'rock,indie,country',
#  'electronic,chillout,german,house,techno',
#  'jazz,experimental,progressive_rock,psychedelic,psychedelic_rock',
#  'indie,female_vocalists,folk,soundtrack,acoustic,love',
#  'indie,indie_pop,mellow,chill',
#  'pop,female_vocalists,rnb,cover',
#  'pop,punk,rap,punk_rock',
#  'hardcore,punk_rock',
#  'pop,female_vocalists,singer_songwriter,90s,love',
#  'metal,black_metal,hardcore,metalcore,post_hardcore,grindcore',
#  'rock,indie,female_vocalists,indie_rock,post_punk',
#  'death_metal,doom_metal',
#  'rock,alternative,alternative_rock,thrash_metal',
#  'rock,alternative,metal,alternative_rock,hard_rock,emo,nu_metal',
#  'electronic,experimental,synthpop',
#  'pop,80s,soul,90s',
#  'electronic,indie,pop,indie_pop,swedish',
#  'jazz,experimental,drum_and_bass',
#  'alternative,indie,female_vocalists',
#  'alternative,post_rock,guitar,noise',
#  'metal,heavy_metal,progressive_metal,power_metal',
#  'alternative,indie,pop,female_vocalists,alternative_rock,chillout,soundtrack',
#  'punk_rock,reggae',
#  'russian,guitar',
#  'female_vocalists,experimental,singer_songwriter,chillout,beautiful,synthpop,chill',
#  'metal,progressive_metal,melodic_death_metal,doom_metal',
#  'rock,alternative,alternative_rock,90s,cover',
#  'indie,female_vocalists,japanese,indie_pop,beautiful',
#  'metal,heavy_metal,thrash_metal,90s,power_metal',
#  'rock,singer_songwriter,male_vocalists,beautiful',
#  'jazz,rap,hip_hop,chill',
#  'instrumental,classical,new_age',
#  'rock,metalcore,emo,post_hardcore',
#  'alternative_rock,hardcore,emo,post_hardcore,screamo',
#  'metal,black_metal,death_metal,grindcore',
#  'rock,instrumental,classical,cover',
#  'hard_rock,heavy_metal',
#  'alternative,indie_rock,piano',
#  'alternative,indie,indie_rock,post_punk,britpop',
#  'death_metal,grindcore',
#  'indie,alternative_rock,indie_rock,hardcore,post_punk,emo,post_hardcore,screamo',
#  'rock,hard_rock,heavy_metal,power_metal',
#  'folk,country',
#  'electronic,indie,trip_hop,idm',
#  'synthpop',
#  'rock,alternative,alternative_rock,country,guitar',
#  'indie,female_vocalists,acoustic,guitar,mellow',
#  'alternative,indie,folk,singer_songwriter,chillout,acoustic,male_vocalists,love,beautiful,mellow,chill',
#  'rock,punk,hardcore,punk_rock,emo,post_hardcore',
#  'female_vocalists,experimental,trip_hop,noise',
#  'rock,experimental',
#  'indie,indie_rock,british,new_wave,indie_pop,synthpop,britpop',
#  'country,male_vocalists',
#  'indie,indie_rock,00s,britpop',
#  'electronic,indie,pop,acoustic,indie_pop,emo,love',
#  'alternative,punk,90s,reggae,ska',
#  'alternative,indie,experimental,folk,american,beautiful',
#  'indie,folk,british,acoustic',
#  'pop,female_vocalists,jazz,folk,blues,american,indie_pop,love,beautiful',
#  'indie,folk,indie_rock,singer_songwriter,acoustic,love,beautiful,mellow',
#  'rock,classic_rock,70s,oldies',
#  'rock,jazz,classic_rock,progressive_rock,70s',
#  'rock,alternative,punk,hardcore,punk_rock,emo,love,screamo',
#  'pop,female_vocalists,dance,hip_hop,rnb,love',
#  'rock,alternative,indie,progressive_rock',
#  'rock,alternative,indie,alternative_rock,punk,indie_rock,90s,grunge',
#  'indie,indie_rock,new_wave,indie_pop',
#  'alternative,indie,acoustic,mellow,chill',
#  'pop,80s,new_wave,synthpop,new_age',
#  'gothic_metal,symphonic_metal',
#  'rock,alternative,indie,guitar,mellow,chill',
#  'rock,classic_rock,blues,psychedelic,60s,psychedelic_rock,guitar,blues_rock',
#  'electronic,alternative,female_vocalists,ambient,experimental,90s,trip_hop,beautiful',
#  'electronic,experimental,instrumental,chillout,hip_hop,trip_hop,downtempo,idm,lounge,chill',
#  'indie,folk,soundtrack,acoustic',
#  'electronic,female_vocalists,ambient',
#  'rock,classic_rock,hard_rock,progressive_rock,british,70s,60s,blues_rock',
#  'ambient,instrumental,chillout,idm,chill',
#  'rock,hard_rock,70s',
#  'indie,indie_rock,progressive_rock,british,blues,britpop',
#  'indie,female_vocalists,folk,trip_hop,indie_pop,cover',
#  'pop,classic_rock,british,70s,60s,male_vocalists,oldies,lounge',
#  'electronic,female_vocalists,chillout,trip_hop,downtempo,french,lounge',
#  'electronic,dance,90s,psychedelic,house,psychedelic_rock,cover',
#  'alternative,soundtrack,emo,screamo',
#  'pop,female_vocalists,synthpop,pop_rock',
#  'rock,alternative_rock,punk,punk_rock,german',
#  'indie,folk,indie_rock,american,indie_pop',
#  'death_metal,melodic_death_metal,grindcore',
#  'soul,90s,rnb',
#  'female_vocalists,singer_songwriter,80s,soundtrack',
#  'experimental,hardcore,metalcore,progressive_metal,grindcore',
#  'rock,alternative,indie,pop,alternative_rock,indie_rock,90s,00s,mellow,chill',
#  'rock,punk,punk_rock,90s,american',
#  'punk_rock,swedish,ska',
#  'folk,dance,german',
#  'alternative,folk',
#  'rock,electronic,alternative,indie,alternative_rock,experimental,indie_rock,british,90s,psychedelic,beautiful,britpop,mellow',
#  'jazz,love',
#  'rock,alternative,female_vocalists,alternative_rock,german,nu_metal',
#  'electronic,indie,pop,female_vocalists,ambient,british,chillout,trip_hop,indie_pop,downtempo,mellow,chill',
#  'electronic,dance,90s,trance,house,techno',
#  'indie,singer_songwriter,british,britpop',
#  'electronic,indie,singer_songwriter,british',
#  'experimental,downtempo,avant_garde',
#  'electronic,alternative,female_vocalists,ambient,experimental,psychedelic,trip_hop,downtempo,love,avant_garde',
#  'electronic,chillout,funk,trip_hop,downtempo,lounge,chill',
#  'indie,experimental,indie_rock,post_rock,noise',
#  'alternative,indie,ambient,chillout,post_rock,beautiful',
#  'alternative_rock,funk,psychedelic_rock',
#  'electronic,experimental,trip_hop,noise',
#  'punk,new_wave,70s',
#  'electronic,alternative,indie,indie_pop,synthpop',
#  'electronic,indie,indie_rock,instrumental,soundtrack,piano,indie_pop,00s,guitar,chill',
#  'electronic,pop,female_vocalists,00s',
#  'indie,experimental,folk,indie_rock,psychedelic,noise,avant_garde',
#  'black_metal,death_metal,doom_metal',
#  'indie,experimental,indie_rock,singer_songwriter,psychedelic,post_rock,post_punk,indie_pop',
#  'metal,death_metal,japanese,screamo',
#  'rap,electro',
#  'electronic,indie,pop,indie_rock,indie_pop,mellow,chill',
#  'indie,experimental,indie_pop,avant_garde',
#  'electronic,alternative,indie,80s,new_wave,post_punk,gothic',
#  'rock,classic_rock,hard_rock,male_vocalists',
#  'pop,dance,soul,rnb',
#  'rock,alternative,indie,pop,indie_rock,british,indie_pop',
#  'electronic,dance,funk,house,electro',
#  'rock,classic_rock,instrumental,progressive_rock,british,psychedelic,70s,psychedelic_rock',
#  'experimental,progressive_rock,funk,avant_garde,ska',
#  'indie,female_vocalists,soundtrack,downtempo',
#  'soul,american,rnb,chill',
#  'rock,folk,blues,cover,blues_rock',
#  'rock,alternative,indie,alternative_rock,indie_rock,american,00s,blues_rock',
#  'electronic,ambient,instrumental,german,techno,electro,synthpop,idm',
#  'rock,alternative,alternative_rock,singer_songwriter,piano,guitar',
#  'rock,alternative,punk,punk_rock,acoustic,american,emo,post_hardcore,beautiful,guitar,mellow',
#  'rock,alternative,pop,female_vocalists,alternative_rock,dance,90s,00s,ska',
#  'electronic,alternative,female_vocalists,chillout,trip_hop,downtempo',
#  'jazz,instrumental,oldies',
#  'classic_rock,punk,punk_rock,cover',
#  'metal,experimental,hardcore,metalcore,screamo,grindcore',
#  'rock,punk,hip_hop,male_vocalists,guitar,pop_rock',
#  'rock,alternative,metal,hard_rock,90s,nu_metal',
#  'chillout,piano,downtempo,lounge',
#  'rock,alternative,german,pop_rock',
#  'indie,folk,chillout,piano',
#  'electronic,female_vocalists,ambient,experimental,lounge',
#  'electronic,chillout,blues,trip_hop,downtempo',
#  'electronic,experimental,chillout,synthpop,mellow,chill',
#  'british,male_vocalists',
#  'rock,90s,acoustic',
#  'indie,female_vocalists,folk,singer_songwriter,chillout,acoustic,mellow',
#  'electronic,alternative_rock,instrumental,new_wave',
#  'rock,indie,alternative_rock,punk,90s,american,post_punk,grunge',
#  'alternative,indie,pop_rock',
#  'indie,folk,beautiful,swedish',
#  'indie,pop,indie_pop,swedish,mellow',
#  'rock,classic_rock,80s',
#  'pop,female_vocalists,singer_songwriter,chillout,acoustic,mellow',
#  'electronic,indie,psychedelic,drum_and_bass',
#  'pop,dance,german,house,techno',
#  'indie,experimental,folk,indie_rock',
#  'electronic,pop,dance,rap,hip_hop,rnb',
#  'psychedelic,new_age',
#  'rock,classic_rock,singer_songwriter,british,70s,male_vocalists',
#  'rock,electronic,alternative,indie,pop,alternative_rock,british,hip_hop,trip_hop,chill',
#  'indie,indie_rock,indie_pop,britpop,swedish',
#  'rock,alternative,indie,punk,indie_rock,hard_rock,dance,post_punk,00s',
#  'electronic,indie_pop',
#  'rock,alternative_rock,experimental,psychedelic_rock,grunge',
#  'pop,80s,soul,funk,american,rnb,synthpop,chill',
#  'soul,rap,hip_hop',
#  'alternative,new_wave,polish',
#  'pop,indie_pop,love,synthpop',
#  'punk,hardcore,punk_rock,emo',
#  'rock,alternative,alternative_rock,punk,funk,00s,swedish',
#  'pop,80s,soul,american,rnb,love',
#  'electronic,ambient,dance,drum_and_bass',
#  'female_vocalists,jazz,chillout,lounge',
#  'blues,60s,guitar,blues_rock',
#  'electronic,trance,dark_ambient',
#  'indie,progressive_rock,psychedelic,psychedelic_rock',
#  'electronic,ambient,chillout,trance,new_age',
#  'post_rock,new_wave,post_punk,russian',
#  'alternative,indie,singer_songwriter,acoustic,piano,beautiful,mellow,chill',
#  'pop,experimental,japanese,power_metal,emo,gothic_metal,symphonic_metal,j_pop,avant_garde',
#  'indie,alternative_rock,experimental,indie_rock,indie_pop,psychedelic_rock',
#  'folk,acoustic,70s',
#  'rock,alternative_rock,indie_rock,hard_rock,psychedelic,psychedelic_rock,00s,grunge,blues_rock',
#  'metal,progressive_metal,melodic_death_metal,gothic_metal',
#  'electronic,dance,british,90s,techno',
#  'rock,indie,alternative_rock,indie_rock,british,post_punk,00s',
#  'rock,alternative_rock,progressive_rock,progressive_metal,funk',
#  'indie,pop,indie_rock,indie_pop',
#  'rock,indie,british,blues,90s,britpop,pop_rock',
#  'female_vocalists,acoustic,country,guitar',
#  'metal,punk,hardcore,punk_rock',
#  'soul,funk,70s,mellow',
#  'electronic,dance,british,industrial,90s,techno',
#  'rock,alternative,indie,alternative_rock,indie_rock,piano,love,beautiful,00s,mellow',
#  'experimental,psychedelic,indie_pop',
#  'rock,new_wave,oldies,pop_rock',
#  'rock,pop,singer_songwriter,90s,beautiful',
#  'alternative,dance,pop_rock',
#  'indie,alternative_rock,indie_rock,post_rock,new_wave,post_punk',
#  'punk,80s,hardcore,punk_rock,post_punk',
#  'rock,electronic,alternative,indie,indie_rock,british,cover',
#  'rock,indie,pop,pop_rock',
#  'rock,pop,dance,80s,soul,funk',
#  'indie,indie_rock,hard_rock,black_metal,death_metal,heavy_metal,rap,industrial,thrash_metal,metalcore,funk,melodic_death_metal,power_metal,post_hardcore,doom_metal,gothic_metal,grunge,symphonic_metal,grindcore,nu_metal',
#  'alternative,indie,alternative_rock,male_vocalists,synthpop,pop_rock',
#  'metal,black_metal,heavy_metal,doom_metal,blues_rock',
#  'instrumental,electro,idm,noise',
#  'rock,alternative,indie,pop,alternative_rock,chillout,soundtrack,90s,piano,love,beautiful,mellow,chill',
#  'pop,female_vocalists,cover,pop_rock',
#  'electronic,experimental,electro,synthpop',
#  'rock,alternative,indie,female_vocalists,cover',
#  'pop,80s,soul,soundtrack,male_vocalists',
#  'electronic,indie,soundtrack,indie_pop,love',
#  'rock,electronic,alternative,indie,alternative_rock,ambient,experimental,british,chillout,beautiful,00s,britpop',
#  'indie,female_vocalists,singer_songwriter,soundtrack,indie_pop',
#  'rock,alternative,punk,grunge',
#  'indie,experimental,folk,indie_rock,psychedelic,indie_pop,noise',
#  'hard_rock,progressive_rock,heavy_metal,doom_metal,psychedelic_rock,swedish',
#  'rock,alternative,emo,post_hardcore,pop_rock',
#  'instrumental,heavy_metal,doom_metal,psychedelic_rock',
#  'classic_rock,folk,singer_songwriter,psychedelic,60s,oldies,psychedelic_rock',
#  'folk,german',
#  'rock,electronic,indie,indie_pop,00s,french,chill',
#  'singer_songwriter,soundtrack,country',
#  'pop,female_vocalists,80s,90s,cover',
#  'electronic,alternative,indie,experimental,indie_rock,indie_pop,drum_and_bass',
#  'female_vocalists,trip_hop,french,lounge',
#  'experimental,instrumental,soul,rap,hip_hop,guitar,chill',
#  'electronic,chillout,trip_hop,french,lounge,chill',
#  'industrial,trance',
#  'ambient,experimental,post_rock,beautiful,mellow',
#  'rock,alternative,indie,pop,alternative_rock,indie_rock,dance,00s,swedish',
#  'rock,electronic,alternative,indie,alternative_rock,indie_rock,british,chillout,post_rock,beautiful',
#  'indie,instrumental,swedish',
#  'post_rock,progressive_metal,doom_metal',
#  'rock,classic_rock,80s,new_wave',
#  'indie_rock,noise',
#  '80s,soul,funk,male_vocalists',
#  'pop,black_metal,rnb',
#  'metal,black_metal,death_metal,progressive_metal,melodic_death_metal',
#  'rock,classic_rock,folk,singer_songwriter,70s,60s',
#  'soundtrack,love',
#  'house,american',
#  'rock,classic_rock,80s,guitar,blues_rock',
#  'death_metal,metalcore,grindcore,avant_garde',
#  'indie,pop,indie_rock,american,indie_pop',
#  'rock,alternative,emo,00s,synthpop',
#  'electronic,alternative,pop,80s,new_wave,synthpop',
#  'female_vocalists,soul,classical,piano,american,rnb',
#  'pop,dance,soul,funk,70s,oldies',
#  'rock,alternative,alternative_rock,90s,funk',
#  'rock,alternative,pop,female_vocalists,swedish',
#  'indie,soundtrack,piano,male_vocalists,mellow',
#  'thrash_metal',
#  'alternative_rock,indie_rock,american',
#  'rock,indie,indie_rock,punk_rock,00s,cover',
#  'female_vocalists,chillout,trip_hop,downtempo,polish',
#  'folk,singer_songwriter,acoustic,male_vocalists,mellow,chill',
#  'electronic,alternative,electro',
#  'dance,rap,hip_hop,american',
#  'rock,alternative,punk,hardcore,punk_rock,emo,post_hardcore',
#  'rock,alternative,indie,alternative_rock,british,trip_hop,00s,britpop',
#  'metal,hard_rock,heavy_metal,hardcore,metalcore,melodic_death_metal',
#  'indie,experimental,progressive_rock,post_hardcore,avant_garde',
#  'rock,alternative,alternative_rock,90s,love',
#  'indie,pop,guitar',
#  'rock,alternative,indie,alternative_rock,indie_rock,british,post_punk,love,beautiful,britpop,mellow',
#  'electronic,ambient,post_rock,house,techno,french',
#  'rock,punk,indie_rock,instrumental,soundtrack,punk_rock,swedish',
#  'classic_rock,folk,singer_songwriter,soundtrack,acoustic,60s,mellow',
#  'rock,alternative,alternative_rock,punk,punk_rock,piano,emo,beautiful',
#  'alternative,indie,pop,alternative_rock,indie_rock,heavy_metal,grunge',
#  'rock,alternative,indie,alternative_rock,punk,indie_rock,punk_rock',
#  'rock,alternative,indie,alternative_rock,indie_rock,cover,blues_rock',
#  'jazz,cover',
#  'rock,electronic,alternative,alternative_rock,ambient,experimental,instrumental,chillout',
#  'rock,indie,pop,folk,singer_songwriter,chillout,blues,acoustic,male_vocalists,guitar,pop_rock,chill',
#  'alternative,indie,ambient,indie_rock,post_rock,britpop',
#  'rock,alternative,indie,female_vocalists,folk,singer_songwriter,indie_pop,french',
#  'death_metal,punk_rock',
#  'rock,alternative,indie,alternative_rock,indie_rock,soundtrack',
#  'indie,indie_rock,american,00s',
#  'electronic,pop,female_vocalists,dance,piano,electro',
#  'indie,french',
#  'jazz,00s,french,cover',
#  'indie,acoustic,reggae,chill,ska',
#  'rock,classic_rock,singer_songwriter,80s,piano,70s,male_vocalists,oldies',
#  'rock,alternative,punk_rock,male_vocalists,emo,love',
#  'alternative,80s,post_punk,gothic',
#  'electronic,chillout,trip_hop,drum_and_bass',
#  'instrumental,chillout,soundtrack,japanese',
#  'rock,alternative,indie,male_vocalists,emo,pop_rock',
#  'jazz,trip_hop,dark_ambient',
#  'rock,alternative,metal,alternative_rock,hard_rock,rap,cover,nu_metal',
#  'rock,alternative,punk,80s,post_punk,gothic',
#  'indie,folk,indie_rock,love,beautiful',
#  'pop,dance,american',
#  'rock,indie,90s,psychedelic,psychedelic_rock,britpop',
#  'indie,folk,british,acoustic,male_vocalists,chill',
#  'rock,soul,blues,funk',
#  'pop,female_vocalists,heavy_metal,thrash_metal,country,noise',
#  'indie,piano,pop_rock',
#  'rock,pop,classic_rock,oldies,00s',
#  'electronic,trip_hop,downtempo,lounge',
#  'ambient,instrumental,classical,piano,new_age',
#  'ambient,psychedelic,trance,downtempo',
#  'indie,folk,singer_songwriter,blues,acoustic,country',
#  'alternative,singer_songwriter,piano,post_punk,male_vocalists,love',
#  'electronic,ambient,experimental,instrumental,chillout,psychedelic,downtempo,idm',
#  'rock,alternative,pop,female_vocalists,experimental,pop_rock',
#  'pop,female_vocalists,dance,hip_hop,american,rnb,00s,pop_rock',
#  'experimental,progressive_rock,psychedelic,german,70s,psychedelic_rock,avant_garde',
#  'electronic,indie,pop,chillout,indie_pop,downtempo,mellow',
#  'electronic,experimental,dark_ambient',
#  'rock,folk,singer_songwriter,chillout,acoustic,american,male_vocalists,love,beautiful,00s,mellow,chill',
#  'rock,alternative,hard_rock,love,beautiful,nu_metal',
#  'alternative,singer_songwriter,soundtrack,blues,piano',
#  'indie,chillout,acoustic,indie_pop,guitar,mellow,chill',
#  'rock,pop,classic_rock,80s,british,male_vocalists,pop_rock',
#  'hip_hop,nu_metal',
#  'experimental,progressive_rock,blues,psychedelic,american,60s,psychedelic_rock,avant_garde',
#  'reggae,downtempo,lounge',
#  'electronic,instrumental,chillout,hip_hop,trip_hop,downtempo,lounge,chill',
#  'alternative,indie,alternative_rock,experimental,80s,american,post_punk,grunge,noise',
#  'electronic,ambient,experimental,90s,idm,chill,drum_and_bass',
#  'pop,male_vocalists,00s',
#  'classic_rock,blues,psychedelic_rock,guitar,blues_rock',
#  'metalcore,russian',
#  'alternative,indie,experimental,soundtrack,mellow',
#  'soul,hip_hop,funk,rnb',
#  'alternative,indie,psychedelic_rock',
#  'alternative,indie,indie_rock,emo,love,pop_rock',
#  'indie,emo,britpop,swedish',
#  'rock,alternative,indie,female_vocalists,alternative_rock,experimental,punk,indie_rock,90s,post_punk,grunge,noise',
#  'ambient,chillout,german,downtempo',
#  'rock,alternative,indie,female_vocalists,singer_songwriter,acoustic',
#  'indie,punk,indie_rock,british,post_punk,00s,britpop',
#  'rock,indie,alternative_rock,folk,indie_rock,singer_songwriter,indie_pop,00s,mellow',
#  'electronic,pop,ambient,chillout,90s,trip_hop,electro,downtempo,french,lounge,chill',
#  'indie,alternative_rock,experimental,post_rock',
#  'industrial,doom_metal,gothic_metal,gothic',
#  'rock,alternative_rock,hard_rock,90s,funk,psychedelic_rock',
#  'rock,indie,indie_rock,post_rock',
#  'ambient,idm',
#  'french,cover,ska',
#  'pop,female_vocalists,dance,soul,90s,hip_hop,rnb,00s',
#  'female_vocalists,oldies,french',
#  'rock,alternative,alternative_rock,ambient,experimental,80s,psychedelic,noise,avant_garde',
#  'electronic,80s,british,new_wave,piano,love,beautiful,synthpop',
#  'classic_rock,folk,70s,mellow',
#  'rock,electronic,alternative,indie,pop,british,beautiful',
#  'electronic,ambient,chillout,german,downtempo,idm,chill',
#  'folk,punk,80s,ska',
#  'black_metal,thrash_metal,avant_garde',
#  'rock,indie_rock,blues,00s,blues_rock',
#  'alternative,indie,folk,chillout,indie_pop,mellow,chill',
#  'rock,alternative,alternative_rock,jazz,experimental,psychedelic,country,psychedelic_rock',
#  'rock,classic_rock,80s,soundtrack,blues,70s,male_vocalists,blues_rock',
#  'electronic,chillout,trip_hop,techno,downtempo',
#  'experimental,indie_rock,psychedelic,psychedelic_rock',
#  'rock,alternative,pop,british,90s,male_vocalists,love,britpop',
#  'electronic,alternative,female_vocalists,ambient,experimental,singer_songwriter,chillout,90s,trip_hop,love,beautiful',
#  'soundtrack,love,cover',
#  'rock,classic_rock,punk,hard_rock,punk_rock,post_punk,70s',
#  'indie,pop,female_vocalists,indie_pop',
#  'electronic,female_vocalists,chillout,trip_hop,lounge',
#  'rock,indie,indie_rock,new_wave,post_punk',
#  'indie,pop,female_vocalists,folk,singer_songwriter,soul,french',
#  'rock,alternative,alternative_rock,punk,punk_rock,american,emo',
#  'rock,indie,beautiful',
#  '80s,soul,funk,rnb',
#  'alternative,indie,folk,soul,chillout,acoustic,00s',
#  'jazz,singer_songwriter,blues,lounge',
#  'rock,alternative,indie,pop,alternative_rock,indie_rock,90s,funk,love,cover,mellow',
#  'experimental,post_rock,dark_ambient',
#  'rock,alternative,metal,alternative_rock,80s,progressive_rock,heavy_metal',
#  'electronic,experimental,industrial,trance,idm',
#  'soul,hip_hop,guitar',
#  'pop,female_vocalists,dance,80s,rap,new_wave',
#  'rock,blues,guitar,cover,blues_rock',
#  'beautiful',
#  'rock,pop,80s,acoustic,pop_rock',
#  'electronic,ambient,chillout,downtempo,idm,chill',
#  'electronic,dance,90s,techno,drum_and_bass',
#  'rock,electronic,alternative,indie,pop,indie_rock,indie_pop,love',
#  'electronic,ambient,house,techno,electro',
#  'rock,alternative,alternative_rock,indie_rock,post_rock,emo,chill',
#  'instrumental,rap,hip_hop,american,post_punk',
#  'rock,alternative,indie_rock,new_wave',
#  'rock,alternative,90s,reggae,ska',
#  'rock,alternative,indie,alternative_rock,indie_rock,indie_pop,love,beautiful,mellow',
#  'rock,alternative,alternative_rock,emo,post_hardcore,screamo',
#  'japanese,indie_pop',
#  'hardcore,industrial,post_hardcore,screamo',
#  'electronic,pop,female_vocalists,japanese,j_pop',
#  'alternative,experimental,progressive_rock',
#  'rock,alternative,alternative_rock,soundtrack,acoustic,country,guitar,pop_rock',
#  'rock,classic_rock,psychedelic_rock,blues_rock',
#  'pop,female_vocalists,90s',
#  'psychedelic,cover',
#  'pop,female_vocalists,90s,beautiful,cover',
#  'electronic,jazz,ambient,chillout,trip_hop,downtempo,mellow,lounge,chill',
#  'classic_rock,80s',
#  'rock,alternative,alternative_rock,punk,emo,screamo',
#  'indie,experimental,indie_rock,90s,noise',
#  'jazz,punk_rock,cover',
#  'electronic,indie,experimental,synthpop',
#  'rock,alternative,alternative_rock,experimental,hard_rock,punk_rock,american,00s',
#  'indie,singer_songwriter,progressive_rock,acoustic,indie_pop,00s',
#  'rock,indie,alternative_rock,00s,britpop',
#  'electronic,alternative,indie,experimental,indie_rock,psychedelic,american,indie_pop,00s',
#  'rock,alternative_rock,hard_rock,american,grunge',
#  'electronic,indie,female_vocalists,experimental,new_wave,indie_pop,love',
#  'indie,pop,folk,indie_rock,indie_pop,swedish',
#  'ambient,progressive_rock,psychedelic,avant_garde',
#  'doom_metal,gothic',
#  'rock,blues,90s,blues_rock',
#  'rock,alternative,alternative_rock,chillout,90s,acoustic,american,love,beautiful,grunge,mellow',
#  'rock,emo,pop_rock',
#  'rock,alternative,indie,female_vocalists,alternative_rock,indie_rock,beautiful,00s',
#  'psychedelic,hip_hop',
#  'progressive_metal,gothic,symphonic_metal',
#  'rock,alternative_rock,metalcore,nu_metal',
#  'electronic,electro,downtempo',
#  'rock,alternative,alternative_rock,punk,indie_rock,punk_rock,emo,love,screamo',
#  'experimental,progressive_rock,progressive_metal',
#  'pop,female_vocalists,jazz,singer_songwriter,blues,piano,mellow',
#  'alternative,indie,pop,alternative_rock,indie_rock,80s,british,new_wave,post_punk,indie_pop,male_vocalists,beautiful,britpop',
#  'rock,alternative,blues,piano',
#  'rock,alternative,indie,folk,indie_rock,indie_pop',
#  'rock,alternative,alternative_rock,progressive_rock,hardcore,emo,post_hardcore,beautiful,screamo',
#  'rock,alternative,punk,emo,guitar',
#  'rock,alternative,indie,indie_rock,post_punk,indie_pop,love,00s,britpop',
#  'ambient,lounge',
#  'rock,alternative,indie,alternative_rock,indie_rock,love,beautiful',
#  'rock,guitar',
#  'rock,psychedelic_rock,blues_rock',
#  'electronic,indie,pop,female_vocalists,dance,british,indie_pop',
#  'rock,alternative,indie,indie_rock,piano,american,indie_pop,mellow',
#  'rock,metal,classic_rock,hard_rock,progressive_rock,heavy_metal,70s',
#  'jazz,instrumental,progressive_rock',
#  'electronic,indie,female_vocalists,french,synthpop',
#  'rock,alternative,alternative_rock,punk,punk_rock,emo,love,pop_rock',
#  'instrumental,soul,hip_hop,funk,trip_hop',
#  'rock,alternative,indie,pop,alternative_rock,british,00s,britpop,mellow',
#  'rock,classic_rock,folk,british,psychedelic,60s',
#  'electronic,indie,experimental,electro',
#  'indie,female_vocalists,indie_pop,guitar',
#  'electronic,alternative,british,pop_rock',
#  'metal,black_metal,symphonic_metal',
#  'experimental,instrumental,progressive_rock,post_rock',
#  'punk,punk_rock,emo',
#  'rock,classic_rock,psychedelic,60s,oldies',
#  'electronic,ambient,chillout,trip_hop,downtempo,french',
#  'pop,female_vocalists,british,reggae,indie_pop,britpop,ska',
#  'black_metal,death_metal,gothic_metal',
#  'alternative,experimental,trip_hop,lounge',
#  'electronic,ambient,german,downtempo',
#  'rock,alternative,indie,female_vocalists,alternative_rock,punk,punk_rock,american,beautiful',
#  'rap,hip_hop,house',
#  'indie,indie_rock,post_rock,britpop',
#  'electronic,electro,french,idm',
#  'rock,alternative,folk,singer_songwriter,blues,male_vocalists,avant_garde',
#  'electronic,dance,house',
#  'indie,singer_songwriter,french',
#  'alternative,indie,female_vocalists,alternative_rock,punk,indie_rock,post_punk',
#  'electronic,female_vocalists,dance,electro,00s,synthpop',
#  'rock,indie,alternative_rock,punk_rock,american,emo,screamo',
#  'industrial,thrash_metal',
#  'electronic,alternative,indie,ambient,experimental,chillout,post_rock,beautiful,mellow',
#  'pop,dance,chillout,90s',
#  'rock,hard_rock,90s,funk',
#  'death_metal,progressive_metal,doom_metal',
#  'rock,electronic,alternative,indie,pop,alternative_rock,indie_rock,american,indie_pop',
#  'alternative,alternative_rock,funk',
#  'pop,female_vocalists,ambient,chillout,lounge,chill',
#  'punk,hardcore,punk_rock,90s,post_hardcore,swedish,screamo',
#  'female_vocalists,piano,french,lounge',
#  'electronic,indie,experimental,indie_rock,chillout,psychedelic,cover',
#  'pop,female_vocalists,folk,singer_songwriter,80s,soul,acoustic,love,mellow',
#  'indie,female_vocalists,singer_songwriter,indie_pop,00s,cover',
#  'indie,indie_rock,american',
#  'hard_rock,heavy_metal,70s,doom_metal',
#  'gothic,dark_ambient',
#  'hardcore,metalcore,melodic_death_metal',
#  'electronic,alternative,indie,pop,alternative_rock,experimental,indie_rock,indie_pop',
#  'rock,piano,male_vocalists,pop_rock',
#  'rock,alternative,alternative_rock,indie_rock,00s',
#  'rock,alternative,indie,female_vocalists,singer_songwriter,post_punk',
#  'indie,female_vocalists,singer_songwriter,guitar,swedish',
#  'indie_rock,beautiful',
#  'punk,hardcore,punk_rock,screamo',
#  'rap,hip_hop,funk,electro',
#  'rock,alternative_rock,indie_rock,hard_rock,psychedelic_rock,blues_rock',
#  'rock,nu_metal',
#  'metal,instrumental,symphonic_metal',
#  'alternative,female_vocalists,singer_songwriter,swedish',
#  'rock,folk,singer_songwriter,60s',
#  'alternative,indie,indie_rock,british,male_vocalists',
#  'alternative,indie,progressive_rock,soundtrack',
#  'pop,folk,singer_songwriter,british,acoustic,male_vocalists',
#  'rock,indie,idm',
#  'electronic,dance,house,techno,idm',
#  'rock,pop,male_vocalists,pop_rock',
#  'female_vocalists,metal,gothic_metal,gothic,cover',
#  'folk,industrial,german',
#  'electronic,instrumental,noise',
#  'thrash_metal,progressive_metal',
#  'pop,dance,chillout',
#  'alternative,pop,dance',
#  'rock,pop,classic_rock,punk,80s,new_wave',
#  'folk,singer_songwriter,chillout,male_vocalists',
#  'jazz,instrumental,piano,french,lounge',
#  'rock,pop,british,soul,chillout,soundtrack,90s,rnb,male_vocalists,love,beautiful,mellow',
#  'power_metal,dark_ambient,grindcore',
#  'electronic,new_wave,synthpop,idm',
#  'indie,hip_hop,american',
#  'death_metal,power_metal',
#  'experimental,instrumental,post_rock,noise',
#  'rock,electronic,classic_rock,experimental,electro,french',
#  'electronic,experimental,soul,rnb,downtempo',
#  'electronic,female_vocalists,ambient,downtempo,synthpop,swedish',
#  'rock,metal,classic_rock,hard_rock,80s,acoustic',
#  'electronic,experimental,instrumental,electro',
#  'rock,alternative,indie,indie_rock,grunge,noise',
#  'rock,classic_rock,hard_rock,80s,heavy_metal',
#  'rock,experimental,psychedelic_rock,00s',
#  'indie,singer_songwriter,british,guitar',
#  'rock,female_vocalists,classic_rock,blues,70s,60s,blues_rock',
#  'experimental,synthpop',
#  'electronic,alternative,british,electro,synthpop',
#  'death_metal,doom_metal,grindcore',
#  'dance,rap,hip_hop,funk,00s',
#  'rock,indie,pop,singer_songwriter,blues,american,male_vocalists,love,00s,mellow,pop_rock,blues_rock',
#  'electronic,indie,ambient,experimental,chillout,indie_pop,downtempo,mellow',
#  'female_vocalists,80s,new_wave,post_punk,gothic,cover',
#  'jazz,dance,soundtrack,oldies',
#  'experimental,instrumental,classical,avant_garde',
#  'power_metal,gothic_metal,gothic,cover,symphonic_metal',
#  'jazz,dark_ambient',
#  'electronic,instrumental,dance,funk,house,french',
#  'electronic,jazz,ambient,experimental,chillout,trip_hop,downtempo,idm,lounge,chill,drum_and_bass',
#  'alternative,indie,alternative_rock,00s',
#  'rock,alternative,indie,pop,alternative_rock,indie_rock,heavy_metal,punk_rock,post_hardcore,grunge',
#  'industrial,new_wave,synthpop,gothic',
#  'electronic,indie,female_vocalists,experimental,post_rock',
#  'rock,female_vocalists,classic_rock,instrumental,blues,psychedelic,70s,oldies,psychedelic_rock,blues_rock',
#  'rock,alternative,female_vocalists,alternative_rock,german',
#  'rock,hard_rock,progressive_rock',
#  'indie,folk,soundtrack,cover',
#  'folk,70s,country',
#  'folk,acoustic,swedish',
#  'soul,70s,60s,oldies',
#  'rock,electronic,alternative,indie,experimental,indie_rock,psychedelic,electro,indie_pop,psychedelic_rock,00s',
#  'indie,pop,german',
#  'ambient,instrumental,guitar,avant_garde',
#  'pop,female_vocalists,love,pop_rock',
#  'alternative,pop,female_vocalists,alternative_rock,singer_songwriter,80s,progressive_rock,british,beautiful',
#  'electronic,female_vocalists,industrial,electro,synthpop',
#  'alternative,indie,folk,indie_rock',
#  'rock,alternative,indie,singer_songwriter,80s,new_wave,post_punk,downtempo,guitar,britpop',
#  'rock,alternative,indie,alternative_rock,folk,indie_rock,indie_pop,00s',
#  'folk,singer_songwriter,soundtrack,acoustic,beautiful,mellow',
#  'rock,indie,indie_rock,british,post_punk,beautiful',
#  'alternative,indie,experimental,folk,singer_songwriter',
#  'alternative_rock,industrial',
#  'jazz,chillout,trip_hop,downtempo,lounge',
#  'rock,electronic,alternative,indie,alternative_rock,experimental,british,piano,beautiful',
#  'jazz,french,lounge',
#  'rock,alternative,alternative_rock,90s,acoustic,love,beautiful,grunge,mellow',
#  'rock,pop,female_vocalists,new_wave,pop_rock',
#  'rock,indie,indie_rock,british,acoustic,piano,britpop',
#  'female_vocalists,jazz,cover',
#  'pop,female_vocalists,chillout,polish',
#  'indie,experimental,instrumental,post_rock,russian',
#  'alternative,experimental,folk,german,gothic',
#  'indie,pop,female_vocalists,singer_songwriter,acoustic,indie_pop,love,mellow,chill',
#  'rock,alternative,indie,alternative_rock,singer_songwriter,blues',
#  'pop,80s,soul,new_wave',
#  'indie,female_vocalists,folk,singer_songwriter',
#  'electronic,psychedelic',
#  'rock,hard_rock,grunge,nu_metal',
#  'electronic,indie,post_rock,german,guitar',
#  'rock,indie,indie_rock,british,indie_pop,britpop',
#  'pop,female_vocalists,jazz,soul,rnb',
#  'alternative,experimental,progressive_rock,funk,psychedelic_rock',
#  'experimental,soul,hip_hop,funk,trip_hop,00s',
#  'rock,alternative,pop,alternative_rock,90s,mellow',
#  'acoustic,country,guitar',
#  'rock,pop,female_vocalists,singer_songwriter,90s,acoustic,country,love,00s,guitar,cover,mellow,pop_rock',
#  'rock,alternative_rock,classic_rock,guitar,blues_rock',
#  'rock,alternative,punk,piano,emo',
#  'female_vocalists,trip_hop,polish',
#  'electronic,chillout,post_rock,downtempo,french,idm',
#  'instrumental,progressive_rock,psychedelic_rock',
#  'instrumental,death_metal,hardcore,british,metalcore,melodic_death_metal',
#  '90s,acoustic,beautiful,mellow',
#  'jazz,piano,cover,lounge',
#  'rock,alternative,indie,alternative_rock,post_rock',
#  'japanese,trip_hop',
#  'indie,indie_rock,soundtrack,post_punk',
#  'rock,alternative,indie,alternative_rock,indie_rock,progressive_rock,british,00s,britpop',
#  'electronic,pop,dance,house,techno',
#  'rock,alternative,pop,ska',
#  'female_vocalists,jazz,soul,chillout,soundtrack,60s,oldies',
#  'rock,electronic,alternative,pop,alternative_rock,british,chillout,hip_hop,trip_hop,00s,chill',
#  'rock,pop,classic_rock,folk,acoustic,70s,60s,male_vocalists,oldies',
#  'rock,alternative_rock,industrial,emo,pop_rock',
#  'alternative,indie,britpop,mellow',
#  'indie_rock,male_vocalists',
#  'rock,pop,classic_rock,singer_songwriter,80s,new_wave,70s',
#  'metal,instrumental,death_metal,metalcore,melodic_death_metal',
#  'alternative,indie,indie_rock,80s,british,new_wave,post_punk,indie_pop,britpop',
#  'female_vocalists,70s,country,oldies,cover',
#  'electronic,80s,industrial,post_punk,avant_garde',
#  'alternative,singer_songwriter,male_vocalists,cover',
#  'psychedelic',
#  'electronic,indie,pop,female_vocalists,dance,british,new_wave,synthpop',
#  'alternative,ambient,experimental,post_rock',
#  'soul,funk,70s,rnb,male_vocalists',
#  'jazz,piano,lounge',
#  'alternative,indie,experimental,folk,singer_songwriter,beautiful',
#  'electronic,indie,pop,female_vocalists,dance,british',
#  'rock,alternative,alternative_rock,90s,beautiful,grunge',
#  'electronic,dance,electro,synthpop',
#  'electronic,indie,dance,chillout,house,electro,mellow,chill',
#  '80s,new_wave,ska',
#  'indie,experimental,folk,acoustic,psychedelic,american,beautiful,00s',
#  'instrumental,progressive_metal,power_metal,symphonic_metal',
#  'dance,soul,70s',
#  'hardcore,acoustic,metalcore,emo,post_hardcore,screamo',
#  'electronic,alternative,pop,female_vocalists,new_wave,electro,synthpop,pop_rock',
#  'electronic,ambient,experimental,instrumental,chillout,post_rock,beautiful,chill',
#  'indie,british,funk,electro',
#  'electronic,downtempo,idm,dark_ambient',
#  'rock,country,beautiful',
#  'rock,pop,classic_rock,funk,70s',
#  'rock,alternative,indie,pop,indie_rock,american,indie_pop,00s',
#  'electronic,alternative,female_vocalists,ambient,experimental,british,trip_hop,avant_garde',
#  'rock,alternative,indie,pop,male_vocalists,love,beautiful,mellow,pop_rock',
#  'rock,metal,alternative_rock,hard_rock,80s,progressive_rock,heavy_metal,thrash_metal',
#  'alternative,piano,mellow',
#  'rock,metal,classic_rock,hard_rock,heavy_metal,british,70s,doom_metal',
#  'rock,experimental,progressive_rock,psychedelic_rock,00s',
#  'classic_rock,british,psychedelic,60s,oldies,love,beautiful',
#  'electronic,experimental,american,indie_pop',
#  'electronic,alternative,female_vocalists,ambient,experimental,psychedelic,avant_garde',
#  'progressive_rock,noise',
#  'electronic,alternative,female_vocalists,ambient,experimental,psychedelic,dark_ambient,avant_garde',
#  'indie,experimental,indie_rock,noise',
#  ...}

# %%
# unique tags in the data

(
    df_songs
    .loc[:,"tags"]
    .dropna()
    .str.split(",")
    .explode()
    .str.strip()
    .unique()
)
# Out:
# array(['rock', 'alternative', 'indie', 'alternative_rock', 'indie_rock',
#        '00s', 'pop', 'british', '90s', 'love', 'britpop', 'grunge',
#        'piano', 'beautiful', 'mellow', 'chillout', 'funk', 'electronic',
#        'dance', 'hip_hop', 'trip_hop', 'metal', 'hard_rock', 'nu_metal',
#        'progressive_rock', 'classic_rock', '80s', '70s', 'experimental',
#        'soundtrack', 'female_vocalists', 'heavy_metal', 'rap', '60s',
#        'post_punk', 'pop_rock', 'punk', 'punk_rock', 'acoustic', 'emo',
#        'new_wave', 'chill', 'indie_pop', 'gothic_metal', 'gothic',
#        'thrash_metal', 'folk', 'singer_songwriter', 'country', 'cover',
#        'blues_rock', 'psychedelic', 'psychedelic_rock', 'guitar',
#        'american', 'ska', 'ambient', 'blues', 'oldies', 'french',
#        'male_vocalists', 'reggae', 'instrumental', 'jazz', 'avant_garde',
#        'industrial', 'german', 'synthpop', 'hardcore', 'metalcore',
#        'screamo', 'post_rock', 'swedish', 'doom_metal', 'power_metal',
#        'rnb', 'soul', 'electro', 'house', 'techno', 'post_hardcore',
#        'progressive_metal', 'russian', 'noise', 'idm', 'symphonic_metal',
#        'dark_ambient', 'drum_and_bass', 'downtempo', 'lounge', 'trance',
#        'new_age', 'black_metal', 'death_metal', 'classical', 'japanese',
#        'melodic_death_metal', 'grindcore', 'j_pop', 'polish'],
#       dtype=object)

# %% [markdown]
# ### Integer Based Columns

# %% [markdown]
# **Key**
#
# **What it means:** The musical key in which the song is composed, represented as integers (e.g., 0 = C, 1 = C#, 2 = D, etc., up to 11).
# - **When value is small:** Represents keys like C or D, often associated with simplicity or familiarity.
# - **When value is large:** Represents keys like A# or B, which may sound brighter or more complex, depending on the context.
#
# ---
#
# **Mode**
#
# **What it means:** Refers to the modality of the song, where 0 = minor (often associated with sadness or tension) and 1 = major (associated with happiness or resolution).
# - **When value is small:** Indicates the song is in a minor mode, creating a more somber or serious tone.
# - **When value is large:** Indicates the song is in a major mode, giving it a cheerful and uplifting feel.
#
# ---
#
# **Time Signature**
#
# **What it means:** The number of beats in each bar of music, typically expressed as an integer (e.g., 4 for 4/4 time).
# - **When value is small:** Indicates fewer beats per measure (e.g., 3), which can create a waltz-like or less conventional rhythm.
# - **When value is large:** Indicates more beats per measure (e.g., 5 or 7), often leading to a more complex or experimental rhythmic structure.
#
#
# > A value of **4** in the time signature typically means the song is in **4/4 time**, also known as "common time." This means there are **4 beats per measure**, and the quarter note gets one beat.
#
# >**Impact of a 4 Time Signature:**
# - **Musical Feel:** It creates a steady, balanced, and natural rhythm that is easy to follow.
# - **Prevalence:** It is the most common time signature in Western music, used in many genres like pop, rock, classical, and jazz.
# - **Examples:** Songs like "Billie Jean" by Michael Jackson or "Shape of You" by Ed Sheeran are in 4/4.

# %%
integer_columns = df_songs.select_dtypes(include="int").columns
integer_columns
# Out:
# Index(['year', 'duration_ms', 'key', 'mode', 'time_signature'], dtype='object')

# %%
df_songs[integer_columns]
# Out:
#        year  duration_ms  key  mode  time_signature
# 0      2004       222200    1     1               4
# 1      2006       258613    2     1               4
# 2      1991       218920    4     0               4
# 3      2004       237026    9     1               4
# 4      2008       238640    7     1               4
# ...     ...          ...  ...   ...             ...
# 50678  2008       273440    6     0               4
# 50679  2004       275133    0     1               4
# 50680  2014       254826   10     0               4
# 50681  2008       243293    4     0               4
# 50682  2008       131960    8     1               4
#
# [50674 rows x 5 columns]

# %%
# statistical summary

(
    df_songs
    .loc[:,integer_columns]
    .drop(columns=["duration_ms"])
    .assign(**{
        col: df_songs[col].astype("object")
        for col in integer_columns.drop("duration_ms")
    })
    .describe()
)
# Out:
#          year    key   mode  time_signature
# count   50674  50674  50674           50674
# unique     75     12      2               5
# top      2007      9      1               4
# freq     4221   5907  31979           44981

# %%
# range of data

(
    df_songs
    .loc[:,integer_columns]
    .assign(duration_minutes=df_songs["duration_ms"].div(1000).div(60))
    .drop(columns=["duration_ms"])
    .agg(["min","max"])
)
# Out:
#      year  key  mode  time_signature  duration_minutes
# min  1900    0     0               0          0.023983
# max  2022   11     1               5         63.606217

# %%
# number of songs per year in data

sns.histplot(df_songs,x="year",bins=df_songs["year"].max() - df_songs["year"].min(),stat="count")
plt.show()

# %%
# most songs from which year(top 5)

(
    df_songs
    .loc[:,"year"]
    .value_counts()
    .head(5)
    .sort_index()
)
# Out:
# year
# 2005    3085
# 2006    3453
# 2007    4221
# 2008    3947
# 2009    3827
# Name: count, dtype: int64

# %% [markdown]
# #### **Keys**

# %%
Musical notes are assigned key values from **0 to 11**, representing all the chromatic notes in an octave. Here’s the mapping:  

| **Key Value** | **Note** |  
|---------------|-----------|  
| 0             | C         |  
| 1             | C# / Db   |  
| 2             | D         |  
| 3             | D# / Eb   |  
| 4             | E         |  
| 5             | F         |  
| 6             | F# / Gb   |  
| 7             | G         |  
| 8             | G# / Ab   |  
| 9             | A         |  
| 10            | A# / Bb   |  
| 11            | B         |  

### Notes Explained:  
- **Sharps (#):** Raise the note by a semitone (e.g., C → C#).  
- **Flats (b):** Lower the note by a semitone (e.g., D → Db).  

This cycle repeats across octaves!
# Out:
#   Cell In[275], line 1
#     Musical notes are assigned key values from **0 to 11**, representing all the chromatic notes in an octave. Here’s the mapping:
#                                                                                                                    ^
# SyntaxError: invalid character '’' (U+2019)

# %% [markdown]
# ####
# **English vs Hindi Notes Comparison**
#
# Here’s a table that maps **Key Value**, **English Notes**, and their corresponding **Hindi Music Notes (Swaras)**:
#
# | **Key Value** | **English Note** | **Hindi Music Note** |
# |---------------|------------------|-----------------------|
# | 0             | C                | Sa                   |
# | 1             | C# / Db          | Komal Re             |
# | 2             | D                | Re                   |
# | 3             | D# / Eb          | Komal Ga             |
# | 4             | E                | Ga                   |
# | 5             | F                | Ma                   |
# | 6             | F# / Gb          | Tivra Ma             |
# | 7             | G                | Pa                   |
# | 8             | G# / Ab          | Komal Dha            |
# | 9             | A                | Dha                  |
# | 10            | A# / Bb          | Komal Ni             |
# | 11            | B                | Ni                   |
#
# **Notes**:
# - In **Hindi classical music**, "Komal" refers to flat (lowered) notes, and "Tivra" refers to sharp (raised) notes.
# - The cycle repeats with "Sa" at the next octave!

# %% [markdown]
# ###
# -----
#
# If a song has a key value of **2**, it means the song is composed in the **D major** or **D minor key**, depending on the **mode** (0 = minor, 1 = major).
#
# **Interpretation**:
# - **Key Value 2 (D):** The tonic note, or "home base," of the song is **D**. All other notes and chords in the song revolve around this note.
# - **In Western Music:**
#   - **D Major:** Bright and uplifting.
#   - **D Minor:** Melancholic or introspective.
# - **In Hindi Classical Music:** This corresponds to the "Re" swara (if D is treated as the Sa of the scale).
#
# The overall mood or emotion of the song will depend on the mode and how the scale is used melodically and harmonically.

# %%
# unique values in the key column

(
    np.sort(df_songs
            .loc[:,"key"]
            .unique())
)

# %%
# percentage of songs wrt to key in the data

(
    df_songs['key']
    .value_counts(normalize=True)
    .mul(100)
    .sort_index()
    .plot(kind='barh',title="Percentage of Songs wrt to Key",xlabel="Percentage")
)

# %%
# countplot for mode

sns.countplot(df_songs, x='mode')
plt.show()

# %%
# unique values for time signature

np.sort(df_songs.loc[:, 'time_signature'].unique())

# %%
# countplot for time signature

sns.countplot(df_songs, x='time_signature')
plt.show()

# %%
df_songs['time_signature'].value_counts(normalize=True).mul(100)

# %%
# statistical summary of time duration

(
    df_songs
    .loc[:,["duration_ms"]]
    .assign(duration_minutes=df_songs["duration_ms"].div(1000).div(60))
    .drop(columns="duration_ms")
    .describe()
)

# %%
# time duration histogram

time_duration_mins = df_songs["duration_ms"].div(1000).div(60)

sns.histplot(time_duration_mins)
plt.xlabel("Time Duration (mins)")
plt.show()

# %% [markdown]
# #### there are songs longer than 60 mins too, matlab outliers to hai, but we don't have to remove it kyunki we have to calculate similarity scores, jo user zyada long songs sunta hai we will recommend it to them

# %%
# time duration boxplot

sns.boxplot(time_duration_mins)
plt.ylabel("Time Duration (mins)")
plt.show()

# %%
# song that is longer than 60 mins
(
    df_songs
    .loc[time_duration_mins > 60]
)

# %% [markdown]
# ### Continuous Columns

# %%
continuous_columns=df_songs.select_dtypes(include='float').columns
continuous_columns

# %% [markdown]
# **Danceability**
#
# **What it means:** Measures how suitable a track is for dancing, based on tempo, rhythm stability, beat strength, and overall regularity.
# - **When value is small:** The song may feel less rhythmic or harder to dance to, like ballads or experimental music.
# - **When value is large:** The song is highly danceable, with a strong beat and rhythmic consistency, ideal for clubs or parties.
#
# ---
#
# **Energy**
#
# **What it means:** Represents the intensity and activity of a song, considering factors like loudness, tempo, and instrumentation.
# - **When value is small:** The song feels mellow, calm, or laid-back, such as acoustic or chill tracks.
# - **When value is large:** The song feels loud, energetic, and lively, often found in rock or EDM genres.
#
# ---
#
# **Loudness**
#
# **What it means:** The overall volume of the song in decibels (dB), averaged over the track.
# - **When value is small:** The song is quieter, suitable for soft or ambient styles.
# - **When value is large:** The song is louder and more powerful, typically associated with dynamic or energetic tracks.
#
# ---
#
# **Speechiness**
#
# **What it means:** Measures the presence of spoken words in a track. A higher value indicates more speech-like content.
# - **When value is small:** The song is more musical, with fewer spoken or rap-like elements.
# - **When value is large:** The track has spoken word, podcast-style content, or heavy rap influence.
#
# ---
#
# **Acousticness**
#
# **What it means:** Reflects how acoustic (non-electronic) the track is.
# - **When value is small:** The track is more electronic or synthetic in nature.
# - **When value is large:** The track is acoustic, featuring instruments like guitar, piano, or strings.
#
# ---
#
# **Instrumentalness**
#
# **What it means:** Predicts the likelihood of a song having no vocals (purely instrumental).
# - **When value is small:** The track likely has vocals or lyrics.
# - **When value is large:** The track is primarily instrumental, like classical or ambient music.
#
# ---
#
# **Liveness**
#
# **What it means:** Measures the presence of a live audience in the recording.
# - **When value is small:** The track sounds studio-produced without live ambiance.
# - **When value is large:** The track feels live, with audience sounds or a concert vibe.
#
# ---
#
# **Valence**
#
# **What it means:** Indicates the positivity or happiness of a track's mood.
# - **When value is small:** The song feels sad, somber, or emotionally heavy.
# - **When value is large:** The song feels cheerful, uplifting, or happy.
#
# ---
#
# **Tempo**
#
# **What it means:** The speed of the song in beats per minute (BPM).
# - **When value is small:** The song is slow-paced, such as ballads or downtempo tracks.
# - **When value is large:** The song is fast-paced, like dance or upbeat genres.

# %%
def numerical_analysis(df,columns):
    for column in columns:
        print(f"Numerical Analysis for column {column}")
        print("Statistical Summary")
        print(df[column].describe())

        fig = plt.figure(figsize=(12,4))
        # hitogram for column
        plt.subplot(1,2,1)
        sns.histplot(df[column])
        plt.title(f"Histogram for {column}")
        # boxplot for column
        plt.subplot(1,2,2)
        sns.boxplot(df[column])
        plt.title(f"Boxplot for {column}")
        plt.show()

        print("#" * 120)
    print("*" * 120)
    print("Pairplot")
    sns.pairplot(df[columns])
    plt.show()

# %%
numerical_analysis(df_songs,continuous_columns)

# %% [markdown]
# #### iss data pe we do collaborative filtering

# %% [markdown]
# ## User and Song data

# %%
# load the dataset

df_users=pd.read_csv(users_data_path)

# %%
df_users.head()

# %% [markdown]
# ##### ye data batata hai ki user ne ek song ko kitni baar play kiya hai

# %%
# dataset info

df_users=df_users.info()

# %%
# check for duplicates

df_users.duplicated(subset=["track_id","user_id"]).sum()

# %%
#missing values

df_users.isna().sum()

# %%
# unqiue users in the data

(
    df_users
    .loc[:,"user_id"]
    .nunique()
)
